# %% [markdown]
# <a href="https://colab.research.google.com/github/pauloacs/DeepCFD/blob/main/TF2.4_burguers_ident.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing **latex** & pyDOE

# %%
! sudo apt-get install texlive-latex-recommended 
! sudo apt-get install dvipng texlive-latex-extra texlive-fonts-recommended  
! wget http://mirrors.ctan.org/macros/latex/contrib/type1cm.zip 
! unzip type1cm.zip -d /tmp/type1cm 
! cd /tmp/type1cm/type1cm/ && sudo latex type1cm.ins
! sudo mkdir /usr/share/texmf/tex/latex/type1cm 
! sudo cp /tmp/type1cm/type1cm/type1cm.sty /usr/share/texmf/tex/latex/type1cm 
! sudo texhash 
# !apt install cm-super
# !pip install --upgrade pyDOE

# %% [markdown]
# # FIGURES

# %%
import numpy as np
import matplotlib as mpl
from datetime import datetime
import sys
import os
import json

def saveResultDir(save_path, save_hp):
    now = datetime.now()
    scriptName =  os.path.splitext(os.path.basename(sys.argv[0]))[0]
    resDir = os.path.join(save_path, "results", f"{now.strftime('%Y%m%d-%H%M%S')}-{scriptName}")
    os.mkdir(resDir)
    print("Saving results to directory ", resDir)
    savefig(os.path.join(resDir, "graph"))
    with open(os.path.join(resDir, "hp.json"), "w") as f:
        json.dump(save_hp, f)


# MIT License
# 
# Copyright (c) 2018 maziarraissi
# 
# https://github.com/maziarraissi/PINNs

def figsize(scale, nplots = 1):
    fig_width_pt = 390.0                          # Get this from LaTeX using \the\textwidth
    inches_per_pt = 1.0/72.27                       # Convert pt to inch
    golden_mean = (np.sqrt(5.0)-1.0)/2.0            # Aesthetic ratio (you could change this)
    fig_width = fig_width_pt*inches_per_pt*scale    # width in inches
    fig_height = nplots*fig_width*golden_mean              # height in inches
    fig_size = [fig_width,fig_height]
    return fig_size

pgf_with_latex = {                      # setup matplotlib to use latex for output
    "pgf.texsystem": "pdflatex",        # change this if using xetex or lautex
    "text.usetex": True,                # use LaTeX to write all text
    "font.family": "serif",
    "font.serif": [],                   # blank entries should cause plots to inherit fonts from the document
    "font.sans-serif": [],
    "font.monospace": [],
    "axes.labelsize": 10,               # LaTeX default is 10pt font.
    "font.size": 10,
    "legend.fontsize": 8,               # Make the legend/label fonts a little smaller
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "figure.figsize": figsize(1.0),     # default fig size of 0.9 textwidth
    "pgf.preamble": [
        r"\usepackage[utf8x]{inputenc}",    # use utf8 fonts becasue your computer can handle it :)
        r"\usepackage[T1]{fontenc}",        # plots will be generated using this preamble
        ]
    }
mpl.rcParams.update(pgf_with_latex)

import matplotlib.pyplot as plt

# I make my own newfig and savefig functions
def newfig(width, nplots = 1):
    fig = plt.figure(figsize=figsize(width, nplots))
    ax = fig.add_subplot(111)
    return fig, ax

def savefig(filename, crop = True):
    if crop == True:
#        plt.savefig('{}.pgf'.format(filename), bbox_inches='tight', pad_inches=0)
        plt.savefig('{}.pdf'.format(filename), bbox_inches='tight', pad_inches=0)
        # plt.savefig('{}.eps'.format(filename), bbox_inches='tight', pad_inches=0)
        plt.savefig('{}.png'.format(filename), bbox_inches='tight', pad_inches=0)
    else:
#        plt.savefig('{}.pgf'.format(filename))
        plt.savefig('{}.pdf'.format(filename))
        # plt.savefig('{}.eps'.format(filename))
        plt.savefig('{}.png'.format(filename))

## Simple plot
#fig, ax  = newfig(1.0)
#
#def ema(y, a):
#    s = []
#    s.append(y[0])
#    for t in range(1, len(y)):
#        s.append(a * y[t] + (1-a) * s[t-1])
#    return np.array(s)
#    
#y = [0]*200
#y.extend([20]*(1000-len(y)))
#s = ema(y, 0.01)
#
#ax.plot(s)
#ax.set_xlabel('X Label')
#ax.set_ylabel('EMA')
#
#savefig('ema')

# %% [markdown]
# # INFORMATIONS

# %%
import json
import tensorflow as tf
import time
from datetime import datetime


class Logger(object):
    def __init__(self, hp):
        print("Hyperparameters:")
        print(json.dumps(hp, indent=2))
        print()

        print("TensorFlow version: {}".format(tf.__version__))
        print("Eager execution: {}".format(tf.executing_eagerly()))
        print("GPU-accerelated: {}".format(tf.test.is_gpu_available()))

        self.start_time = time.time()
        self.prev_time = self.start_time
        self.frequency = hp["log_frequency"]

    def get_epoch_duration(self):
        now = time.time()
        edur = datetime.fromtimestamp(now - self.prev_time) \
            .strftime("%S.%f")[:-5]
        self.prev_time = now
        return edur

    def get_elapsed(self):
        return datetime.fromtimestamp(time.time() - self.start_time) \
                .strftime("%M:%S")

    def get_error_u(self):
        return self.error_fn()

    def set_error_fn(self, error_fn):
        self.error_fn = error_fn

    def log_train_start(self, model, model_description=False):
        print("\nTraining started")
        print("================")
        self.model = model
        if model_description:
            print(model.summary())

    def log_train_epoch(self, epoch, loss, custom="", is_iter=False):
        if epoch % self.frequency == 0:
            name = 'nt_epoch' if is_iter else 'tf_epoch'
            print(f"{name} = {epoch:6d}  " +
                  f"elapsed = {self.get_elapsed()} " +
                  f"(+{self.get_epoch_duration()})  " +
                  f"loss = {loss:.4e}  " + custom)

    def log_train_opt(self, name):
        print(f"-- Starting {name} optimization --")

    def log_train_end(self, epoch, custom=""):
        print("==================")
        print(f"Training finished (epoch {epoch}): " +
              f"duration = {self.get_elapsed()}  " +
              f"error = {self.get_error_u():.4e}  " + custom)

# %% [markdown]
# Defining the costum NN

# %%
import tensorflow as tf
import numpy as np

class NeuralNetwork(object):
    def __init__(self, hp, logger, ub, lb):

        layers = hp["layers"]

        # Setting up the optimizers with the hyper-parameters
        self.nt_config = Struct()
        self.nt_config.learningRate = hp["nt_lr"]
        self.nt_config.maxIter = hp["nt_epochs"]
        self.nt_config.nCorrection = hp["nt_ncorr"]
        self.nt_config.tolFun = 1.0 * np.finfo(float).eps
        self.tf_epochs = hp["tf_epochs"]
        self.tf_optimizer = tf.keras.optimizers.Adam(
            learning_rate=hp["tf_lr"],
            beta_1=hp["tf_b1"],
            epsilon=hp["tf_eps"])

        self.dtype = "float64"
        # Descriptive Keras model
        tf.keras.backend.set_floatx(self.dtype)
        self.model = tf.keras.Sequential()
        self.model.add(tf.keras.layers.InputLayer(input_shape=(layers[0],)))
        self.model.add(tf.keras.layers.Lambda(
            lambda X: 2.0*(X - lb)/(ub - lb) - 1.0))
        for width in layers[1:-1]:
            self.model.add(tf.keras.layers.Dense(
                width, activation=tf.nn.tanh,
                kernel_initializer="glorot_normal"))
        self.model.add(tf.keras.layers.Dense(
                layers[-1], activation=None,
                kernel_initializer="glorot_normal"))

        # Computing the sizes of weights/biases for future decomposition
        self.sizes_w = []
        self.sizes_b = []
        for i, width in enumerate(layers):
            if i != 1:
                self.sizes_w.append(int(width * layers[1]))
                self.sizes_b.append(int(width if i != 0 else layers[1]))

        self.logger = logger

    # Defining custom loss
    # @tf.function
    def loss(self, u, u_pred):
        return tf.reduce_mean(tf.square(u - u_pred))

    # @tf.function
    def grad(self, X, u):
        with tf.GradientTape() as tape:
            loss_value = self.loss(u, self.model(X))
        grads = tape.gradient(loss_value, self.wrap_training_variables())
        return loss_value, grads

    def wrap_training_variables(self):
        var = self.model.trainable_variables
        return var

    def get_params(self, numpy=False):
        return []

    def get_weights(self, convert_to_tensor=True):
        w = []
        for layer in self.model.layers[1:]:
            weights_biases = layer.get_weights()
            weights = weights_biases[0].flatten()
            biases = weights_biases[1]
            w.extend(weights)
            w.extend(biases)
        if convert_to_tensor:
            w = self.tensor(w)
        return w

    def set_weights(self, w):
        for i, layer in enumerate(self.model.layers[1:]):
            start_weights = sum(self.sizes_w[:i]) + sum(self.sizes_b[:i])
            end_weights = sum(self.sizes_w[:i+1]) + sum(self.sizes_b[:i])
            weights = w[start_weights:end_weights]
            w_div = int(self.sizes_w[i] / self.sizes_b[i])
            weights = tf.reshape(weights, [w_div, self.sizes_b[i]])
            biases = w[end_weights:end_weights + self.sizes_b[i]]
            weights_biases = [weights, biases]
            layer.set_weights(weights_biases)

    def get_loss_and_flat_grad(self, X, u):
        def loss_and_flat_grad(w):
            with tf.GradientTape() as tape:
                self.set_weights(w)
                loss_value = self.loss(u, self.model(X))
            grad = tape.gradient(loss_value, self.wrap_training_variables())
            grad_flat = []
            for g in grad:
                grad_flat.append(tf.reshape(g, [-1]))
            grad_flat = tf.concat(grad_flat, 0)
            return loss_value, grad_flat

        return loss_and_flat_grad

    def tf_optimization(self, X_u, u):
        self.logger.log_train_opt("Adam")
        for epoch in range(self.tf_epochs):
            loss_value = self.tf_optimization_step(X_u, u)
            self.logger.log_train_epoch(epoch, loss_value)

    # @tf.function
    def tf_optimization_step(self, X_u, u):
        loss_value, grads = self.grad(X_u, u)
        self.tf_optimizer.apply_gradients(
                zip(grads, self.wrap_training_variables()))
        return loss_value

    def nt_optimization(self, X_u, u):
        self.logger.log_train_opt("LBFGS")
        loss_and_flat_grad = self.get_loss_and_flat_grad(X_u, u)
        # tfp.optimizer.lbfgs_minimize(
        #   loss_and_flat_grad,
        #   initial_position=self.get_weights(),
        #   num_correction_pairs=nt_config.nCorrection,
        #   max_iterations=nt_config.maxIter,
        #   f_relative_tolerance=nt_config.tolFun,
        #   tolerance=nt_config.tolFun,
        #   parallel_iterations=6)
        self.nt_optimization_steps(loss_and_flat_grad)

    def nt_optimization_steps(self, loss_and_flat_grad):
        lbfgs(loss_and_flat_grad,
              self.get_weights(),
              self.nt_config, Struct(), True,
              lambda epoch, loss, is_iter:
              self.logger.log_train_epoch(epoch, loss, "", is_iter))

    def fit(self, X_u, u):
        self.logger.log_train_start(self)

        # Creating the tensors
        X_u = self.tensor(X_u)
        u = self.tensor(u)

        # Optimizing
        self.tf_optimization(X_u, u)
        self.nt_optimization(X_u, u)

        self.logger.log_train_end(self.tf_epochs + self.nt_config.maxIter)

    def predict(self, X_star):
        u_pred = self.model(X_star)
        return u_pred.numpy()

    def summary(self):
        return self.model.summary()

    def tensor(self, X):
        return tf.convert_to_tensor(X, dtype=self.dtype)

# %% [markdown]
# ## Defining **lbfgs**

# %%
#%% Adapted from https://github.com/yaroslavvb/stuff/blob/master/eager_lbfgs/eager_lbfgs.py

import tensorflow as tf
import numpy as np
import time

# Time tracking functions
global_time_list = []
global_last_time = 0
def reset_time():
  global global_time_list, global_last_time
  global_time_list = []
  global_last_time = time.perf_counter()
  
def record_time():
  global global_last_time, global_time_list
  new_time = time.perf_counter()
  global_time_list.append(new_time - global_last_time)
  global_last_time = time.perf_counter()
  #print("step: %.2f"%(global_time_list[-1]*1000))

def last_time():
  """Returns last interval records in millis."""
  global global_last_time, global_time_list
  if global_time_list:
    return 1000 * global_time_list[-1]
  else:
    return 0

def dot(a, b):
  """Dot product function since TensorFlow doesn't have one."""
  return tf.reduce_sum(a*b)

def verbose_func(s):
  print(s)

final_loss = None
times = []
def lbfgs(opfunc, x, config, state, do_verbose, log_fn):
  """port of lbfgs.lua, using TensorFlow eager mode.
  """

  if config.maxIter == 0:
    return

  global final_loss, times
  
  maxIter = config.maxIter
  maxEval = config.maxEval or maxIter*1.25
  tolFun = config.tolFun or 1e-5
  tolX = config.tolX or 1e-19
  nCorrection = config.nCorrection or 100
  lineSearch = config.lineSearch
  lineSearchOpts = config.lineSearchOptions
  learningRate = config.learningRate or 1
  isverbose = config.verbose or False

  # verbose function
  if isverbose:
    verbose = verbose_func
  else:
    verbose = lambda x: None

    # evaluate initial f(x) and df/dx
  f, g = opfunc(x)

  f_hist = [f]
  currentFuncEval = 1
  state.funcEval = state.funcEval + 1
  p = g.shape[0]

  # check optimality of initial point
  tmp1 = tf.abs(g)
  if tf.reduce_sum(tmp1) <= tolFun:
    verbose("optimality condition below tolFun")
    return x, f_hist

  # optimize for a max of maxIter iterations
  nIter = 0
  times = []
  while nIter < maxIter:
    start_time = time.time()
    
    # keep track of nb of iterations
    nIter = nIter + 1
    state.nIter = state.nIter + 1

    ############################################################
    ## compute gradient descent direction
    ############################################################
    if state.nIter == 1:
      d = -g
      old_dirs = []
      old_stps = []
      Hdiag = 1
    else:
      # do lbfgs update (update memory)
      y = g - g_old
      s = d*t
      ys = dot(y, s)
      
      if ys > 1e-10:
        # updating memory
        if len(old_dirs) == nCorrection:
          # shift history by one (limited-memory)
          del old_dirs[0]
          del old_stps[0]

        # store new direction/step
        old_dirs.append(s)
        old_stps.append(y)

        # update scale of initial Hessian approximation
        Hdiag = ys/dot(y, y)

      # compute the approximate (L-BFGS) inverse Hessian 
      # multiplied by the gradient
      k = len(old_dirs)

      # need to be accessed element-by-element, so don't re-type tensor:
      ro = [0]*nCorrection
      for i in range(k):
        ro[i] = 1/dot(old_stps[i], old_dirs[i])
        

      # iteration in L-BFGS loop collapsed to use just one buffer
      # need to be accessed element-by-element, so don't re-type tensor:
      al = [0]*nCorrection

      q = -g
      for i in range(k-1, -1, -1):
        al[i] = dot(old_dirs[i], q) * ro[i]
        q = q - al[i]*old_stps[i]

      # multiply by initial Hessian
      r = q*Hdiag
      for i in range(k):
        be_i = dot(old_stps[i], r) * ro[i]
        r += (al[i]-be_i)*old_dirs[i]
        
      d = r
      # final direction is in r/d (same object)

    g_old = g
    f_old = f
    
    ############################################################
    ## compute step length
    ############################################################
    # directional derivative
    gtd = dot(g, d)

    # check that progress can be made along that direction
    if gtd > -tolX:
      verbose("Can not make progress along direction.")
      break

    # reset initial guess for step size
    if state.nIter == 1:
      tmp1 = tf.abs(g)
      t = min(1, 1/tf.reduce_sum(tmp1))
    else:
      t = learningRate


    # optional line search: user function
    lsFuncEval = 0
    if lineSearch and isinstance(lineSearch) == types.FunctionType:
      # perform line search, using user function
      f,g,x,t,lsFuncEval = lineSearch(opfunc,x,t,d,f,g,gtd,lineSearchOpts)
      f_hist.append(f)
    else:
      # no line search, simply move with fixed-step
      x += t*d
      
      if nIter != maxIter:
        # re-evaluate function only if not in last iteration
        # the reason we do this: in a stochastic setting,
        # no use to re-evaluate that function here
        f, g = opfunc(x)
        lsFuncEval = 1
        f_hist.append(f)


    # update func eval
    currentFuncEval = currentFuncEval + lsFuncEval
    state.funcEval = state.funcEval + lsFuncEval

    ############################################################
    ## check conditions
    ############################################################
    if nIter == maxIter:
      break

    if currentFuncEval >= maxEval:
      # max nb of function evals
      verbose('max nb of function evals')
      break

    tmp1 = tf.abs(g)
    if tf.reduce_sum(tmp1) <=tolFun:
      # check optimality
      verbose('optimality condition below tolFun')
      break
    
    tmp1 = tf.abs(d*t)
    if tf.reduce_sum(tmp1) <= tolX:
      # step size below tolX
      verbose('step size below tolX')
      break

    if tf.abs(f-f_old) < tolX:
      # function value changing less than tolX
      verbose('function value changing less than tolX'+str(tf.abs(f-f_old)))
      break

    if do_verbose:
      log_fn(nIter, f.numpy(), True)
      #print("Step %3d loss %6.5f msec %6.3f"%(nIter, f.numpy(), last_time()))
      record_time()
      times.append(last_time())

    if nIter == maxIter - 1:
      final_loss = f.numpy()


  # save state
  state.old_dirs = old_dirs
  state.old_stps = old_stps
  state.Hdiag = Hdiag
  state.g_old = g_old
  state.f_old = f_old
  state.t = t
  state.d = d

  return x, f_hist, currentFuncEval

# dummy/Struct gives Lua-like struct object with 0 defaults
class dummy(object):
  pass

class Struct(dummy):
  def __getattribute__(self, key):
    if key == '__dict__':
      return super(dummy, self).__getattribute__('__dict__')
    return self.__dict__.get(key, 0)

# %% [markdown]
# # Utilities:
#
#
# 1.   Prepare data function
# 2.   Plotting function

# %%
#%% Utils for Burger's equation

import scipy.io
import numpy as np
import tensorflow as tf
import time
from datetime import datetime
from pyDOE import lhs
import os
import sys
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from scipy.interpolate import griddata
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

# "." for Colab/VSCode, and ".." for GitHub
repoPath = os.path.join(".", "PINNs")
# repoPath = os.path.join("..", "PINNs")
utilsPath = os.path.join(repoPath, "Utilities")
dataPath = os.path.join(repoPath, "main", "Data")
appDataPath = os.path.join(repoPath, "appendix", "Data")

def prep_data(path, N_u=None, N_f=None, N_n=None, q=None, ub=None, lb=None, noise=0.0, idx_t_0=None, idx_t_1=None, N_0=None, N_1=None):
    # Reading external data [t is 100x1, usol is 256x100 (solution), x is 256x1]
    data = scipy.io.loadmat(path)

    # Flatten makes [[]] into [], [:,None] makes it a column vector
    t = data['t'].flatten()[:,None] # T x 1
    x = data['x'].flatten()[:,None] # N x 1

    # Keeping the 2D data for the solution data (real() is maybe to make it float by default, in case of zeroes)
    Exact_u = np.real(data['usol']).T # T x N

    # x = np.load("1d-burgers/data/burgers_x.npy")[:, None]
    # t = np.load("1d-burgers/data/burgers_t.npy")[:, None]
    # Exact_u = np.load("1d-burgers/data/burgers_u.npy").T

    if N_n != None and q != None and ub != None and lb != None and idx_t_0 != None and idx_t_1 != None:
      dt = t[idx_t_1] - t[idx_t_0]
      idx_x = np.random.choice(Exact_u.shape[1], N_n, replace=False) 
      x_0 = x[idx_x,:]
      u_0 = Exact_u[idx_t_0:idx_t_0+1,idx_x].T
      u_0 = u_0 + noise*np.std(u_0)*np.random.randn(u_0.shape[0], u_0.shape[1])
        
      # Boudanry data
      x_1 = np.vstack((lb, ub))
      
      # Test data
      x_star = x
      u_star = Exact_u[idx_t_1,:]

      # Load IRK weights
      tmp = np.float32(np.loadtxt(os.path.join(utilsPath, "IRK_weights", "Butcher_IRK%d.txt" % (q)), ndmin = 2))
      IRK_weights = np.reshape(tmp[0:q**2+q], (q+1,q))
      IRK_times = tmp[q**2+q:]

      return x, t, dt, Exact_u, x_0, u_0, x_1, x_star, u_star, IRK_weights, IRK_times

    # Meshing x and t in 2D (256,100)
    X, T = np.meshgrid(x,t)

    # Preparing the inputs x and t (meshed as X, T) for predictions in one single array, as X_star
    X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))

    # Preparing the testing u_star
    u_star = Exact_u.flatten()[:,None]
                
    # Noiseless data TODO: add support for noisy data    
    idx = np.random.choice(X_star.shape[0], N_u, replace=False)
    X_u_train = X_star[idx,:]
    u_train = u_star[idx,:]

    if N_0 != None and N_1 != None:
      Exact_u = Exact_u.T
      idx_x = np.random.choice(Exact_u.shape[0], N_0, replace=False)
      x_0 = x[idx_x,:]
      u_0 = Exact_u[idx_x,idx_t_0][:,None]
      u_0 = u_0 + noise*np.std(u_0)*np.random.randn(u_0.shape[0], u_0.shape[1])
          
      idx_x = np.random.choice(Exact_u.shape[0], N_1, replace=False)
      x_1 = x[idx_x,:]
      u_1 = Exact_u[idx_x,idx_t_1][:,None]
      u_1 = u_1 + noise*np.std(u_1)*np.random.randn(u_1.shape[0], u_1.shape[1])
      
      dt = np.asscalar(t[idx_t_1] - t[idx_t_0])        
      q = int(np.ceil(0.5*np.log(np.finfo(float).eps)/np.log(dt)))

      # Load IRK weights
      tmp = np.float32(np.loadtxt(os.path.join(utilsPath, "IRK_weights", "Butcher_IRK%d.txt" % (q)), ndmin = 2))
      weights =  np.reshape(tmp[0:q**2+q], (q+1,q))     
      IRK_alpha = weights[0:-1,:]
      IRK_beta = weights[-1:,:] 
      return x_0, u_0, x_1, u_1, x, t, dt, q, Exact_u, IRK_alpha, IRK_beta

    if N_f == None:
      lb = X_star.min(axis=0)
      ub = X_star.max(axis=0) 
      return x, t, X, T, Exact_u, X_star, u_star, X_u_train, u_train, ub, lb

    # Domain bounds (lowerbounds upperbounds) [x, t], which are here ([-1.0, 0.0] and [1.0, 1.0])
    lb = X_star.min(axis=0)
    ub = X_star.max(axis=0) 
    # Getting the initial conditions (t=0)
    xx1 = np.hstack((X[0:1,:].T, T[0:1,:].T))
    uu1 = Exact_u[0:1,:].T
    # Getting the lowest boundary conditions (x=-1) 
    xx2 = np.hstack((X[:,0:1], T[:,0:1]))
    uu2 = Exact_u[:,0:1]
    # Getting the highest boundary conditions (x=1) 
    xx3 = np.hstack((X[:,-1:], T[:,-1:]))
    uu3 = Exact_u[:,-1:]
    # Stacking them in multidimensional tensors for training (X_u_train is for now the continuous boundaries)
    X_u_train = np.vstack([xx1, xx2, xx3])
    u_train = np.vstack([uu1, uu2, uu3])

    # Generating the x and t collocation points for f, with each having a N_f size
    # We pointwise add and multiply to spread the LHS over the 2D domain
    X_f_train = lb + (ub-lb)*lhs(2, N_f)

    # Generating a uniform random sample from ints between 0, and the size of x_u_train, of size N_u (initial data size) and without replacement (unique)
    idx = np.random.choice(X_u_train.shape[0], N_u, replace=False)
    # Getting the corresponding X_u_train (which is now scarce boundary/initial coordinates)
    X_u_train = X_u_train[idx,:]
    # Getting the corresponding u_train
    u_train = u_train [idx,:]

    return x, t, X, T, Exact_u, X_star, u_star, X_u_train, u_train, X_f_train, ub, lb

def plot_inf_cont_results(X_star, u_pred, X_u_train, u_train, Exact_u, X, T, x, t, save_path=None, save_hp=None):

  # Interpolating the results on the whole (x,t) domain.
  # griddata(points, values, points at which to interpolate, method)
  U_pred = griddata(X_star, u_pred, (X, T), method='cubic')

  # Creating the figures
  fig, ax = newfig(1.0, 1.1)
  ax.axis('off')

  ####### Row 0: u(t,x) ##################    
  gs0 = gridspec.GridSpec(1, 2)
  gs0.update(top=1-0.06, bottom=1-1/3, left=0.15, right=0.85, wspace=0)
  ax = plt.subplot(gs0[:, :])

  h = ax.imshow(U_pred.T, interpolation='nearest', cmap='rainbow', 
                extent=[t.min(), t.max(), x.min(), x.max()], 
                origin='lower', aspect='auto')
  divider = make_axes_locatable(ax)
  cax = divider.append_axes("right", size="5%", pad=0.05)
  fig.colorbar(h, cax=cax)

  ax.plot(X_u_train[:,1], X_u_train[:,0], 'kx', label = 'Data (%d points)' % (u_train.shape[0]), markersize = 4, clip_on = False)

  line = np.linspace(x.min(), x.max(), 2)[:,None]
  ax.plot(t[25]*np.ones((2,1)), line, 'w-', linewidth = 1)
  ax.plot(t[50]*np.ones((2,1)), line, 'w-', linewidth = 1)
  ax.plot(t[75]*np.ones((2,1)), line, 'w-', linewidth = 1)    

  ax.set_xlabel('$t$')
  ax.set_ylabel('$x$')
  ax.legend(frameon=False, loc = 'best')
  ax.set_title('$u(t,x)$', fontsize = 10)

  ####### Row 1: u(t,x) slices ##################    
  gs1 = gridspec.GridSpec(1, 3)
  gs1.update(top=1-1/3, bottom=0, left=0.1, right=0.9, wspace=0.5)

  ax = plt.subplot(gs1[0, 0])
  ax.plot(x,Exact_u[25,:], 'b-', linewidth = 2, label = 'Exact')       
  ax.plot(x,U_pred[25,:], 'r--', linewidth = 2, label = 'Prediction')
  ax.set_xlabel('$x$')
  ax.set_ylabel('$u(t,x)$')    
  ax.set_title('$t = 0.25$', fontsize = 10)
  ax.axis('square')
  ax.set_xlim([-1.1,1.1])
  ax.set_ylim([-1.1,1.1])

  ax = plt.subplot(gs1[0, 1])
  ax.plot(x,Exact_u[50,:], 'b-', linewidth = 2, label = 'Exact')       
  ax.plot(x,U_pred[50,:], 'r--', linewidth = 2, label = 'Prediction')
  ax.set_xlabel('$x$')
  ax.set_ylabel('$u(t,x)$')
  ax.axis('square')
  ax.set_xlim([-1.1,1.1])
  ax.set_ylim([-1.1,1.1])
  ax.set_title('$t = 0.50$', fontsize = 10)
  ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.35), ncol=5, frameon=False)

  ax = plt.subplot(gs1[0, 2])
  ax.plot(x,Exact_u[75,:], 'b-', linewidth = 2, label = 'Exact')       
  ax.plot(x,U_pred[75,:], 'r--', linewidth = 2, label = 'Prediction')
  ax.set_xlabel('$x$')
  ax.set_ylabel('$u(t,x)$')
  ax.axis('square')
  ax.set_xlim([-1.1,1.1])
  ax.set_ylim([-1.1,1.1])    
  ax.set_title('$t = 0.75$', fontsize = 10)

  if save_path != None and save_hp != None:
      saveResultDir(save_path, save_hp)

  else:
    plt.show()

def plot_inf_disc_results(x_star, idx_t_0, idx_t_1, x_0, u_0, ub, lb, u_1_pred, Exact_u, x, t, save_path=None, save_hp=None):
  fig, ax = newfig(1.0, 1.2)
  ax.axis('off')
  
  ####### Row 0: h(t,x) ##################    
  gs0 = gridspec.GridSpec(1, 2)
  gs0.update(top=1-0.06, bottom=1-1/2 + 0.1, left=0.15, right=0.85, wspace=0)
  ax = plt.subplot(gs0[:, :])
  
  h = ax.imshow(Exact_u.T, interpolation='nearest', cmap='rainbow', 
                extent=[t.min(), t.max(), x_star.min(), x_star.max()], 
                origin='lower', aspect='auto')
  divider = make_axes_locatable(ax)
  cax = divider.append_axes("right", size="5%", pad=0.05)
  fig.colorbar(h, cax=cax)
      
  line = np.linspace(x.min(), x.max(), 2)[:,None]
  ax.plot(t[idx_t_0]*np.ones((2,1)), line, 'w-', linewidth = 1)
  ax.plot(t[idx_t_1]*np.ones((2,1)), line, 'w-', linewidth = 1)
  
  ax.set_xlabel('$t$')
  ax.set_ylabel('$x$')
  leg = ax.legend(frameon=False, loc = 'best')
  ax.set_title('$u(t,x)$', fontsize = 10)
  
  
  ####### Row 1: h(t,x) slices ##################    
  gs1 = gridspec.GridSpec(1, 2)
  gs1.update(top=1-1/2-0.05, bottom=0.15, left=0.15, right=0.85, wspace=0.5)
  
  ax = plt.subplot(gs1[0, 0])
  ax.plot(x,Exact_u[idx_t_0,:], 'b-', linewidth = 2) 
  ax.plot(x_0, u_0, 'rx', linewidth = 2, label = 'Data')      
  ax.set_xlabel('$x$')
  ax.set_ylabel('$u(t,x)$')    
  ax.set_title('$t = %.2f$' % (t[idx_t_0]), fontsize = 10)
  ax.set_xlim([lb-0.1, ub+0.1])
  ax.legend(loc='upper center', bbox_to_anchor=(0.8, -0.3), ncol=2, frameon=False)


  ax = plt.subplot(gs1[0, 1])
  ax.plot(x, Exact_u[idx_t_1,:], 'b-', linewidth = 2, label = 'Exact') 
  ax.plot(x_star, u_1_pred, 'r--', linewidth = 2, label = 'Prediction')      
  ax.set_xlabel('$x$')
  ax.set_ylabel('$u(t,x)$')    
  ax.set_title('$t = %.2f$' % (t[idx_t_1]), fontsize = 10)    
  ax.set_xlim([lb-0.1, ub+0.1])
  
  ax.legend(loc='upper center', bbox_to_anchor=(0.1, -0.3), ncol=2, frameon=False)

  if save_path != None and save_hp != None:
      saveResultDir(save_path, save_hp)

  else:
    plt.show()


def plot_ide_disc_results(x_star, t_star, idx_t_0, idx_t_1, x_0, u_0, x_1, u_1,
  ub, lb, u_1_pred, Exact, lambda_1_value, lambda_1_value_noisy, lambda_2_value, lambda_2_value_noisy,
  x, t, save_path=None, save_hp=None):  
  fig, ax = newfig(1.0, 1.5)
  ax.axis('off')
  
  gs0 = gridspec.GridSpec(1, 2)
  gs0.update(top=1-0.06, bottom=1-1/3+0.05, left=0.15, right=0.85, wspace=0)
  ax = plt.subplot(gs0[:, :])
      
  h = ax.imshow(Exact, interpolation='nearest', cmap='rainbow',
                extent=[t_star.min(),t_star.max(), lb[0], ub[0]],
                origin='lower', aspect='auto')
  divider = make_axes_locatable(ax)
  cax = divider.append_axes("right", size="5%", pad=0.05)
  fig.colorbar(h, cax=cax)
  
  line = np.linspace(x_star.min(), x_star.max(), 2)[:,None]
  ax.plot(t_star[idx_t_0]*np.ones((2,1)), line, 'w-', linewidth = 1.0)
  ax.plot(t_star[idx_t_1]*np.ones((2,1)), line, 'w-', linewidth = 1.0)    
  ax.set_xlabel('$t$')
  ax.set_ylabel('$x$')
  ax.set_title('$u(t,x)$', fontsize = 10)
  
  gs1 = gridspec.GridSpec(1, 2)
  gs1.update(top=1-1/3-0.1, bottom=1-2/3, left=0.15, right=0.85, wspace=0.5)

  ax = plt.subplot(gs1[0, 0])
  ax.plot(x_star,Exact[:,idx_t_0][:,None], 'b', linewidth = 2, label = 'Exact')
  ax.plot(x_0, u_0, 'rx', linewidth = 2, label = 'Data')
  ax.set_xlabel('$x$')
  ax.set_ylabel('$u(t,x)$')
  ax.set_title('$t = %.2f$\n%d trainng data' % (t_star[idx_t_0], u_0.shape[0]), fontsize = 10)
  
  ax = plt.subplot(gs1[0, 1])
  ax.plot(x_star,Exact[:,idx_t_1][:,None], 'b', linewidth = 2, label = 'Exact')
  ax.plot(x_1, u_1, 'rx', linewidth = 2, label = 'Data')
  ax.set_xlabel('$x$')
  ax.set_ylabel('$u(t,x)$')
  ax.set_title('$t = %.2f$\n%d trainng data' % (t_star[idx_t_1], u_1.shape[0]), fontsize = 10)
  ax.legend(loc='upper center', bbox_to_anchor=(-0.3, -0.3), ncol=2, frameon=False)
  
  gs2 = gridspec.GridSpec(1, 2)
  gs2.update(top=1-2/3-0.05, bottom=0, left=0.15, right=0.85, wspace=0.0)
  
  ax = plt.subplot(gs2[0, 0])
  ax.axis('off')
  nu = 0.01/np.pi
  s1 = r'$\begin{tabular}{ |c|c| }  \hline Correct PDE & $u_t + u u_x + %.6f u_{xx} = 0$ \\  \hline Identified PDE (clean data) & ' % (nu)
  s2 = r'$u_t + %.3f u u_x + %.6f u_{xx} = 0$ \\  \hline ' % (lambda_1_value, lambda_2_value)
  s3 = r'Identified PDE (1\% noise) & '
  s4 = r'$u_t + %.3f u u_x + %.6f u_{xx} = 0$  \\  \hline ' % (lambda_1_value_noisy, lambda_2_value_noisy)
  s5 = r'\end{tabular}$'
  s = s1+s2+s3+s4+s5
  ax.text(-0.1,0.2,s)

  if save_path != None and save_hp != None:
      saveResultDir(save_path, save_hp)

  else:
    plt.show()

def plot_ide_cont_results(X_star, u_pred, X_u_train, u_train,
  Exact_u, X, T, x, t, lambda_1_value, lambda_1_value_noisy, lambda_2_value, lambda_2_value_noisy):
    fig, ax = newfig(1.0, 1.4)
    ax.axis('off')

    U_pred = griddata(X_star, u_pred.flatten(), (X, T), method='cubic')
    
    ####### Row 0: u(t,x) ##################    
    gs0 = gridspec.GridSpec(1, 2)
    gs0.update(top=1-0.06, bottom=1-1.0/3.0+0.06, left=0.15, right=0.85, wspace=0)
    ax = plt.subplot(gs0[:, :])
    
    h = ax.imshow(U_pred.T, interpolation='nearest', cmap='rainbow', 
                  extent=[t.min(), t.max(), x.min(), x.max()], 
                  origin='lower', aspect='auto')
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    fig.colorbar(h, cax=cax)
    
    ax.plot(X_u_train[:,1], X_u_train[:,0], 'kx', label = 'Data (%d points)' % (u_train.shape[0]), markersize = 2, clip_on = False)
    
    line = np.linspace(x.min(), x.max(), 2)[:,None]
    ax.plot(t[25]*np.ones((2,1)), line, 'w-', linewidth = 1)
    ax.plot(t[50]*np.ones((2,1)), line, 'w-', linewidth = 1)
    ax.plot(t[75]*np.ones((2,1)), line, 'w-', linewidth = 1)
    
    ax.set_xlabel('$t$')
    ax.set_ylabel('$x$')
    ax.legend(loc='upper center', bbox_to_anchor=(1.0, -0.125), ncol=5, frameon=False)
    ax.set_title('$u(t,x)$', fontsize = 10)
    
    ####### Row 1: u(t,x) slices ##################    
    gs1 = gridspec.GridSpec(1, 3)
    gs1.update(top=1-1.0/3.0-0.1, bottom=1.0-2.0/3.0, left=0.1, right=0.9, wspace=0.5)
    
    ax = plt.subplot(gs1[0, 0])
    ax.plot(x,Exact_u[25,:], 'b-', linewidth = 2, label = 'Exact')
    ax.plot(x,U_pred[25,:], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')    
    ax.set_title('$t = 0.25$', fontsize = 10)
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])
    
    ax = plt.subplot(gs1[0, 1])
    ax.plot(x,Exact_u[50,:], 'b-', linewidth = 2, label = 'Exact')       
    ax.plot(x,U_pred[50,:], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])
    ax.set_title('$t = 0.50$', fontsize = 10)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.35), ncol=5, frameon=False)
    
    ax = plt.subplot(gs1[0, 2])
    ax.plot(x,Exact_u[75,:], 'b-', linewidth = 2, label = 'Exact')       
    ax.plot(x,U_pred[75,:], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])    
    ax.set_title('$t = 0.75$', fontsize = 10)
    
    ####### Row 3: Identified PDE ##################    
    gs2 = gridspec.GridSpec(1, 3)
    gs2.update(top=1.0-2.0/3.0, bottom=0, left=0.0, right=1.0, wspace=0.0)
    
    ax = plt.subplot(gs2[:, :])
    ax.axis('off')
    s1 = r'$\begin{tabular}{ |c|c| }  \hline Correct PDE & $u_t + u u_x - 0.0031831 u_{xx} = 0$ \\  \hline Identified PDE (clean data) & '
    s2 = r'$u_t + %.5f u u_x - %.7f u_{xx} = 0$ \\  \hline ' % (lambda_1_value, lambda_2_value)
    s3 = r'Identified PDE (1\% noise) & '
    s4 = r'$u_t + %.5f u u_x - %.7f u_{xx} = 0$  \\  \hline ' % (lambda_1_value_noisy, lambda_2_value_noisy)
    s5 = r'\end{tabular}$'
    s = s1+s2+s3+s4+s5
    ax.text(0.1,0.1,s)
    plt.show()
    savefig('/content/Burgers_identification')

# %% [markdown]
# # RUnning

# %%
import sys
import json
import os
import tensorflow as tf
import numpy as np
import tensorflow_probability as tfp

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# HYPER PARAMETERS

hp = {}
# Data size on the solution u
hp["N_u"] = 2000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 200
hp["tf_lr"] = 0.01
hp["tf_b1"] = 0.9
hp["tf_eps"] = None
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 5000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 10

#%% DEFINING THE MODEL

class BurgersInformedNN(NeuralNetwork):
    def __init__(self, hp, logger, ub, lb):
        super().__init__(hp, logger, ub, lb)

        # Defining the two additional trainable variables for identification
        self.lambda_1 = tf.Variable([0.0], dtype=self.dtype)
        self.lambda_2 = tf.Variable([-6.0], dtype=self.dtype)

  # The actual PINN
    def f_model(self, X_u):
      l1, l2 = self.get_params()
    # Separating the collocation coordinates
      x_f = tf.convert_to_tensor(X_u[:, 0:1], dtype=self.dtype)
      t_f = tf.convert_to_tensor(X_u[:, 1:2], dtype=self.dtype)

      # Using the new GradientTape paradigm of TF2.0,
      # which keeps track of operations to get the gradient at runtime
      with tf.GradientTape(persistent=True) as tape:
        # Watching the two inputs we’ll need later, x and t
        tape.watch(x_f)
        tape.watch(t_f)
        # Packing together the inputs
        X_f = tf.stack([x_f[:,0], t_f[:,0]], axis=1)


        # Getting the prediction
        u = self.model(X_f)
        # Deriving INSIDE the tape (since we’ll need the x derivative of this later, u_xx)
        u_x = tape.gradient(u, x_f)

      # Getting the other derivatives
      u_xx = tape.gradient(u_x, x_f)
      u_t = tape.gradient(u, t_f)

      # Letting the tape go
      del tape

      # Buidling the PINNs
      return u_t + l1*u*u_x - l2*u_xx

  # Defining custom loss
    def loss(self, u, u_pred):
        f_pred = self.f_model(self.X_u)
        return tf.reduce_mean(tf.square(u - u_pred)) + \
              tf.reduce_mean(tf.square(f_pred))

    def wrap_training_variables(self):
      var = self.model.trainable_variables
      var.extend([self.lambda_1, self.lambda_2])
      return var

    def get_weights(self):
        w = super().get_weights(convert_to_tensor=False)
        w.extend(self.lambda_1.numpy())
        w.extend(self.lambda_2.numpy())
        return tf.convert_to_tensor(w, dtype=self.dtype)

    def set_weights(self, w):
      super().set_weights(w)
      self.lambda_1.assign([w[-2]])
      self.lambda_2.assign([w[-1]])

    def get_params(self, numpy=False):
      l1 = self.lambda_1
      l2 = tf.exp(self.lambda_2)
      if numpy:
          return l1.numpy()[0], l2.numpy()[0]
      return l1, l2

    def fit(self, X_u, u):
      self.X_u =  tf.convert_to_tensor(X_u, dtype=self.dtype)
      super().fit(X_u, u)

    def predict(self, X_star):
      u_star = self.model(X_star)
      f_star = self.f_model(X_star)
      return u_star.numpy(), f_star.numpy()

# %% TRAINING THE MODEL


# Getting the data
path = os.path.join("/content/drive/MyDrive/PINNs-TF2.0/1d-burgers/data", "burgers_shock.mat")
x, t, X, T, Exact_u, X_star, u_star, \
        X_u_train, u_train, ub, lb = prep_data(path, hp["N_u"], noise=0.0)
lambdas_star = (1.0, 0.01/np.pi)

# Creating the model
logger = Logger(hp)
pinn = BurgersInformedNN(hp, logger, ub, lb)

# Defining the error function for the logger and training
def error():
  l1, l2 = pinn.get_params(numpy=True)
  l1_star, l2_star = lambdas_star
  error_lambda_1 = np.abs(l1 - l1_star) / l1_star
  error_lambda_2 = np.abs(l2 - l2_star) / l2_star
  return (error_lambda_1 + error_lambda_2) / 2

logger.set_error_fn(error)
pinn.fit(X_u_train, u_train)

# Getting the model predictions, from the same (x,t) that the predictions were previously gotten from
u_pred, f_pred = pinn.predict(X_star)
lambda_1_pred, lambda_2_pred = pinn.get_params(numpy=True)

# Noise case
x, t, X, T, Exact_u, X_star, u_star, \
        X_u_train, u_train, ub, lb = prep_data(path, hp["N_u"], noise=0.01)
pinn = BurgersInformedNN(hp, logger, ub, lb)
pinn.fit(X_u_train, u_train)
lambda_1_pred_noise, lambda_2_pred_noise = pinn.get_params(numpy=True)

print("l1: ", lambda_1_pred)
print("l2: ", lambda_2_pred)
print("l1_noise: ", lambda_1_pred_noise)
print("l2_noise: ", lambda_2_pred_noise)

# %%
#%% PLOTTING
plot_ide_cont_results(X_star, u_pred, X_u_train, u_train,
        Exact_u, X, T, x, t, lambda_1_pred, lambda_1_pred_noise, lambda_2_pred, lambda_2_pred_noise)

# %% [markdown]
# # DEEPER NN

# %%
import sys
import json
import os
import tensorflow as tf
import numpy as np
import tensorflow_probability as tfp

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# HYPER PARAMETERS

hp = {}
# Data size on the solution u
hp["N_u"] = 2000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 200
hp["tf_lr"] = 0.01
hp["tf_b1"] = 0.9
hp["tf_eps"] = None
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 5000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 10

#%% DEFINING THE MODEL

class BurgersInformedNN(NeuralNetwork):
    def __init__(self, hp, logger, ub, lb):
        super().__init__(hp, logger, ub, lb)

        # Defining the two additional trainable variables for identification
        self.lambda_1 = tf.Variable([0.0], dtype=self.dtype)
        self.lambda_2 = tf.Variable([-6.0], dtype=self.dtype)

  # The actual PINN
    def f_model(self, X_u):
      l1, l2 = self.get_params()
    # Separating the collocation coordinates
      x_f = tf.convert_to_tensor(X_u[:, 0:1], dtype=self.dtype)
      t_f = tf.convert_to_tensor(X_u[:, 1:2], dtype=self.dtype)

      # Using the new GradientTape paradigm of TF2.0,
      # which keeps track of operations to get the gradient at runtime
      with tf.GradientTape(persistent=True) as tape:
        # Watching the two inputs we’ll need later, x and t
        tape.watch(x_f)
        tape.watch(t_f)
        # Packing together the inputs
        X_f = tf.stack([x_f[:,0], t_f[:,0]], axis=1)


        # Getting the prediction
        u = self.model(X_f)
        # Deriving INSIDE the tape (since we’ll need the x derivative of this later, u_xx)
        u_x = tape.gradient(u, x_f)

      # Getting the other derivatives
      u_xx = tape.gradient(u_x, x_f)
      u_t = tape.gradient(u, t_f)

      # Letting the tape go
      del tape

      # Buidling the PINNs
      return u_t + l1*u*u_x - l2*u_xx

  # Defining custom loss
    def loss(self, u, u_pred):
        f_pred = self.f_model(self.X_u)
        return tf.reduce_mean(tf.square(u - u_pred)) + \
              tf.reduce_mean(tf.square(f_pred))

    def wrap_training_variables(self):
      var = self.model.trainable_variables
      var.extend([self.lambda_1, self.lambda_2])
      return var

    def get_weights(self):
        w = super().get_weights(convert_to_tensor=False)
        w.extend(self.lambda_1.numpy())
        w.extend(self.lambda_2.numpy())
        return tf.convert_to_tensor(w, dtype=self.dtype)

    def set_weights(self, w):
      super().set_weights(w)
      self.lambda_1.assign([w[-2]])
      self.lambda_2.assign([w[-1]])

    def get_params(self, numpy=False):
      l1 = self.lambda_1
      l2 = tf.exp(self.lambda_2)
      if numpy:
          return l1.numpy()[0], l2.numpy()[0]
      return l1, l2

    def fit(self, X_u, u):
      self.X_u =  tf.convert_to_tensor(X_u, dtype=self.dtype)
      super().fit(X_u, u)

    def predict(self, X_star):
      u_star = self.model(X_star)
      f_star = self.f_model(X_star)
      return u_star.numpy(), f_star.numpy()

# %% TRAINING THE MODEL


# Getting the data
path = os.path.join("/content/drive/MyDrive/PINNs-TF2.0/1d-burgers/data", "burgers_shock.mat")
x, t, X, T, Exact_u, X_star, u_star, \
        X_u_train, u_train, ub, lb = prep_data(path, hp["N_u"], noise=0.0)
lambdas_star = (1.0, 0.01/np.pi)

# Creating the model
logger = Logger(hp)
pinn = BurgersInformedNN(hp, logger, ub, lb)

# Defining the error function for the logger and training
def error():
  l1, l2 = pinn.get_params(numpy=True)
  l1_star, l2_star = lambdas_star
  error_lambda_1 = np.abs(l1 - l1_star) / l1_star
  error_lambda_2 = np.abs(l2 - l2_star) / l2_star
  return (error_lambda_1 + error_lambda_2) / 2

logger.set_error_fn(error)
pinn.fit(X_u_train, u_train)

# Getting the model predictions, from the same (x,t) that the predictions were previously gotten from
u_pred, f_pred = pinn.predict(X_star)
lambda_1_pred, lambda_2_pred = pinn.get_params(numpy=True)

# Noise case
x, t, X, T, Exact_u, X_star, u_star, \
        X_u_train, u_train, ub, lb = prep_data(path, hp["N_u"], noise=0.01)
pinn = BurgersInformedNN(hp, logger, ub, lb)
pinn.fit(X_u_train, u_train)
lambda_1_pred_noise, lambda_2_pred_noise = pinn.get_params(numpy=True)

print("l1: ", lambda_1_pred)
print("l2: ", lambda_2_pred)
print("l1_noise: ", lambda_1_pred_noise)
print("l2_noise: ", lambda_2_pred_noise)
# Out:
# Hyperparameters:
# {
#   "N_u": 2000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     1
#   ],
#   "tf_epochs": 200,
#   "tf_lr": 0.01,
#   "tf_b1": 0.9,
#   "tf_eps": null,
#   "nt_epochs": 5000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: True
#
# Training started
# ================
# -- Starting Adam optimization --
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# tf_epoch =      0  elapsed = 00:00 (+00.3)  loss = 8.9510e-01
# tf_epoch =     10  elapsed = 00:00 (+00.6)  loss = 1.4925e-01
# tf_epoch =     20  elapsed = 00:01 (+00.6)  loss = 1.3415e-01
# tf_epoch =     30  elapsed = 00:02 (+00.6)  loss = 9.8702e-02
# tf_epoch =     40  elapsed = 00:02 (+00.6)  loss = 9.2799e-02
# tf_epoch =     50  elapsed = 00:03 (+00.6)  loss = 8.4365e-02
# tf_epoch =     60  elapsed = 00:04 (+00.6)  loss = 7.0166e-02
# tf_epoch =     70  elapsed = 00:04 (+00.6)  loss = 5.4321e-02
# tf_epoch =     80  elapsed = 00:05 (+00.6)  loss = 3.8759e-02
# tf_epoch =     90  elapsed = 00:06 (+00.6)  loss = 9.9654e-02
# tf_epoch =    100  elapsed = 00:06 (+00.6)  loss = 2.9511e-02
# tf_epoch =    110  elapsed = 00:07 (+00.6)  loss = 2.9043e-02
# tf_epoch =    120  elapsed = 00:07 (+00.6)  loss = 2.4061e-02
# tf_epoch =    130  elapsed = 00:08 (+00.6)  loss = 2.2280e-02
# tf_epoch =    140  elapsed = 00:09 (+00.6)  loss = 2.0874e-02
# tf_epoch =    150  elapsed = 00:09 (+00.6)  loss = 1.9922e-02
# tf_epoch =    160  elapsed = 00:10 (+00.6)  loss = 1.8914e-02
# tf_epoch =    170  elapsed = 00:11 (+00.6)  loss = 2.3349e-02
# tf_epoch =    180  elapsed = 00:11 (+00.6)  loss = 1.7658e-02
# tf_epoch =    190  elapsed = 00:12 (+00.6)  loss = 1.7066e-02
# -- Starting LBFGS optimization --
# nt_epoch =     10  elapsed = 00:13 (+01.5)  loss = 1.5129e-02
# nt_epoch =     20  elapsed = 00:14 (+00.8)  loss = 1.3384e-02
# nt_epoch =     30  elapsed = 00:15 (+00.9)  loss = 1.2215e-02
# nt_epoch =     40  elapsed = 00:16 (+00.9)  loss = 1.1383e-02
# nt_epoch =     50  elapsed = 00:17 (+01.0)  loss = 1.0587e-02
# nt_epoch =     60  elapsed = 00:18 (+01.0)  loss = 9.6309e-03
# nt_epoch =     70  elapsed = 00:19 (+01.0)  loss = 8.4092e-03
# nt_epoch =     80  elapsed = 00:20 (+01.0)  loss = 7.3470e-03
# nt_epoch =     90  elapsed = 00:21 (+01.0)  loss = 6.3121e-03
# nt_epoch =    100  elapsed = 00:22 (+01.0)  loss = 5.3156e-03
# nt_epoch =    110  elapsed = 00:23 (+01.0)  loss = 4.4218e-03
# nt_epoch =    120  elapsed = 00:24 (+01.0)  loss = 3.9703e-03
# nt_epoch =    130  elapsed = 00:25 (+01.0)  loss = 3.4363e-03
# nt_epoch =    140  elapsed = 00:26 (+01.0)  loss = 3.0378e-03
# nt_epoch =    150  elapsed = 00:27 (+01.0)  loss = 2.6865e-03
# nt_epoch =    160  elapsed = 00:28 (+01.0)  loss = 2.5258e-03
# nt_epoch =    170  elapsed = 00:29 (+01.0)  loss = 2.2751e-03
# nt_epoch =    180  elapsed = 00:30 (+01.0)  loss = 2.0500e-03
# nt_epoch =    190  elapsed = 00:31 (+01.0)  loss = 1.8683e-03
# nt_epoch =    200  elapsed = 00:33 (+01.0)  loss = 1.7343e-03
# nt_epoch =    210  elapsed = 00:34 (+01.0)  loss = 1.5277e-03
# nt_epoch =    220  elapsed = 00:35 (+01.0)  loss = 1.2883e-03
# nt_epoch =    230  elapsed = 00:36 (+01.0)  loss = 1.1641e-03
# nt_epoch =    240  elapsed = 00:37 (+01.0)  loss = 1.0594e-03
# nt_epoch =    250  elapsed = 00:38 (+01.0)  loss = 9.7014e-04
# nt_epoch =    260  elapsed = 00:39 (+01.0)  loss = 8.6007e-04
# nt_epoch =    270  elapsed = 00:40 (+01.0)  loss = 7.6451e-04
# nt_epoch =    280  elapsed = 00:41 (+01.0)  loss = 8.3181e-04
# nt_epoch =    290  elapsed = 00:42 (+01.0)  loss = 5.9490e-04
# nt_epoch =    300  elapsed = 00:43 (+01.0)  loss = 5.2791e-04
# nt_epoch =    310  elapsed = 00:44 (+01.0)  loss = 4.9265e-04
# nt_epoch =    320  elapsed = 00:45 (+01.0)  loss = 4.6270e-04
# nt_epoch =    330  elapsed = 00:46 (+01.0)  loss = 4.3669e-04
# nt_epoch =    340  elapsed = 00:47 (+01.0)  loss = 3.9925e-04
# nt_epoch =    350  elapsed = 00:48 (+01.0)  loss = 3.8476e-04
# nt_epoch =    360  elapsed = 00:49 (+01.0)  loss = 3.6426e-04
# nt_epoch =    370  elapsed = 00:50 (+01.0)  loss = 3.4961e-04
# nt_epoch =    380  elapsed = 00:51 (+00.9)  loss = 3.3345e-04
# nt_epoch =    390  elapsed = 00:52 (+01.0)  loss = 3.1031e-04
# nt_epoch =    400  elapsed = 00:53 (+01.0)  loss = 2.9196e-04
# nt_epoch =    410  elapsed = 00:54 (+01.0)  loss = 2.6103e-04
# nt_epoch =    420  elapsed = 00:55 (+01.0)  loss = 2.4672e-04
# nt_epoch =    430  elapsed = 00:56 (+01.0)  loss = 2.3091e-04
# nt_epoch =    440  elapsed = 00:57 (+01.0)  loss = 2.1934e-04
# nt_epoch =    450  elapsed = 00:58 (+01.0)  loss = 2.0739e-04
# nt_epoch =    460  elapsed = 00:59 (+01.0)  loss = 1.9950e-04
# nt_epoch =    470  elapsed = 01:00 (+01.0)  loss = 1.9480e-04
# nt_epoch =    480  elapsed = 01:01 (+01.0)  loss = 1.9178e-04
# nt_epoch =    490  elapsed = 01:02 (+01.0)  loss = 1.8647e-04
# nt_epoch =    500  elapsed = 01:03 (+01.0)  loss = 1.8334e-04
# nt_epoch =    510  elapsed = 01:04 (+01.0)  loss = 1.7719e-04
# nt_epoch =    520  elapsed = 01:05 (+01.0)  loss = 1.7466e-04
# nt_epoch =    530  elapsed = 01:06 (+01.0)  loss = 1.7851e-04
# nt_epoch =    540  elapsed = 01:07 (+01.0)  loss = 1.6617e-04
# nt_epoch =    550  elapsed = 01:08 (+01.0)  loss = 1.6345e-04
# nt_epoch =    560  elapsed = 01:09 (+01.0)  loss = 1.5865e-04
# nt_epoch =    570  elapsed = 01:10 (+01.0)  loss = 1.5221e-04
# nt_epoch =    580  elapsed = 01:11 (+01.0)  loss = 1.4727e-04
# nt_epoch =    590  elapsed = 01:12 (+01.0)  loss = 1.4497e-04
# nt_epoch =    600  elapsed = 01:13 (+01.0)  loss = 1.4072e-04
# nt_epoch =    610  elapsed = 01:14 (+01.0)  loss = 1.3536e-04
# nt_epoch =    620  elapsed = 01:15 (+01.0)  loss = 1.2952e-04
# nt_epoch =    630  elapsed = 01:16 (+01.0)  loss = 1.2599e-04
# nt_epoch =    640  elapsed = 01:17 (+01.0)  loss = 1.2199e-04
# nt_epoch =    650  elapsed = 01:18 (+00.9)  loss = 1.1756e-04
# nt_epoch =    660  elapsed = 01:19 (+00.9)  loss = 1.1294e-04
# nt_epoch =    670  elapsed = 01:20 (+01.0)  loss = 1.0953e-04
# nt_epoch =    680  elapsed = 01:21 (+01.0)  loss = 1.0564e-04
# nt_epoch =    690  elapsed = 01:22 (+01.0)  loss = 1.0177e-04
# nt_epoch =    700  elapsed = 01:23 (+01.0)  loss = 9.9182e-05
# nt_epoch =    710  elapsed = 01:24 (+01.0)  loss = 9.6813e-05
# nt_epoch =    720  elapsed = 01:25 (+01.0)  loss = 9.3828e-05
# nt_epoch =    730  elapsed = 01:27 (+01.0)  loss = 8.9984e-05
# nt_epoch =    740  elapsed = 01:28 (+01.0)  loss = 8.6629e-05
# nt_epoch =    750  elapsed = 01:29 (+01.0)  loss = 8.6355e-05
# nt_epoch =    760  elapsed = 01:30 (+00.9)  loss = 8.0994e-05
# nt_epoch =    770  elapsed = 01:31 (+00.9)  loss = 7.8890e-05
# nt_epoch =    780  elapsed = 01:32 (+01.0)  loss = 7.6168e-05
# nt_epoch =    790  elapsed = 01:33 (+01.0)  loss = 7.2679e-05
# nt_epoch =    800  elapsed = 01:34 (+01.0)  loss = 7.2443e-05
# nt_epoch =    810  elapsed = 01:35 (+01.0)  loss = 6.9238e-05
# nt_epoch =    820  elapsed = 01:36 (+01.0)  loss = 6.8305e-05
# nt_epoch =    830  elapsed = 01:37 (+00.9)  loss = 6.6527e-05
# nt_epoch =    840  elapsed = 01:38 (+01.0)  loss = 6.4543e-05
# nt_epoch =    850  elapsed = 01:39 (+01.0)  loss = 6.1546e-05
# nt_epoch =    860  elapsed = 01:40 (+01.0)  loss = 5.7673e-05
# nt_epoch =    870  elapsed = 01:41 (+01.0)  loss = 5.6350e-05
# nt_epoch =    880  elapsed = 01:42 (+01.0)  loss = 5.4194e-05
# nt_epoch =    890  elapsed = 01:43 (+01.0)  loss = 5.1926e-05
# nt_epoch =    900  elapsed = 01:44 (+01.0)  loss = 4.9543e-05
# nt_epoch =    910  elapsed = 01:45 (+01.0)  loss = 4.7697e-05
# nt_epoch =    920  elapsed = 01:46 (+01.0)  loss = 4.6219e-05
# nt_epoch =    930  elapsed = 01:47 (+01.0)  loss = 4.5038e-05
# nt_epoch =    940  elapsed = 01:48 (+01.0)  loss = 4.4107e-05
# nt_epoch =    950  elapsed = 01:49 (+01.0)  loss = 4.2241e-05
# nt_epoch =    960  elapsed = 01:50 (+01.0)  loss = 4.1004e-05
# nt_epoch =    970  elapsed = 01:51 (+01.0)  loss = 4.0241e-05
# nt_epoch =    980  elapsed = 01:52 (+01.0)  loss = 3.8872e-05
# nt_epoch =    990  elapsed = 01:53 (+00.9)  loss = 3.7864e-05
# nt_epoch =   1000  elapsed = 01:54 (+01.0)  loss = 3.6989e-05
# nt_epoch =   1010  elapsed = 01:55 (+00.9)  loss = 3.6167e-05
# nt_epoch =   1020  elapsed = 01:56 (+01.0)  loss = 3.5616e-05
# nt_epoch =   1030  elapsed = 01:57 (+01.0)  loss = 3.5046e-05
# nt_epoch =   1040  elapsed = 01:58 (+01.0)  loss = 3.4543e-05
# nt_epoch =   1050  elapsed = 01:59 (+01.0)  loss = 3.3812e-05
# nt_epoch =   1060  elapsed = 02:00 (+00.9)  loss = 3.3376e-05
# nt_epoch =   1070  elapsed = 02:01 (+01.0)  loss = 3.2677e-05
# nt_epoch =   1080  elapsed = 02:02 (+01.0)  loss = 3.1797e-05
# nt_epoch =   1090  elapsed = 02:03 (+01.0)  loss = 3.1284e-05
# nt_epoch =   1100  elapsed = 02:04 (+01.0)  loss = 3.0925e-05
# nt_epoch =   1110  elapsed = 02:05 (+01.0)  loss = 3.0341e-05
# nt_epoch =   1120  elapsed = 02:06 (+01.0)  loss = 2.9667e-05
# nt_epoch =   1130  elapsed = 02:07 (+01.0)  loss = 2.8488e-05
# nt_epoch =   1140  elapsed = 02:08 (+01.0)  loss = 2.7690e-05
# nt_epoch =   1150  elapsed = 02:09 (+00.9)  loss = 2.6981e-05
# nt_epoch =   1160  elapsed = 02:10 (+00.9)  loss = 2.6346e-05
# nt_epoch =   1170  elapsed = 02:11 (+01.0)  loss = 2.5560e-05
# nt_epoch =   1180  elapsed = 02:12 (+01.0)  loss = 2.4743e-05
# nt_epoch =   1190  elapsed = 02:13 (+01.0)  loss = 2.3929e-05
# nt_epoch =   1200  elapsed = 02:14 (+01.0)  loss = 2.3277e-05
# nt_epoch =   1210  elapsed = 02:15 (+00.9)  loss = 2.2694e-05
# nt_epoch =   1220  elapsed = 02:16 (+01.0)  loss = 2.2231e-05
# nt_epoch =   1230  elapsed = 02:17 (+01.0)  loss = 2.1508e-05
# nt_epoch =   1240  elapsed = 02:18 (+01.0)  loss = 2.0734e-05
# nt_epoch =   1250  elapsed = 02:19 (+01.0)  loss = 2.0167e-05
# nt_epoch =   1260  elapsed = 02:20 (+01.0)  loss = 1.9784e-05
# nt_epoch =   1270  elapsed = 02:21 (+01.0)  loss = 1.9315e-05
# nt_epoch =   1280  elapsed = 02:22 (+01.0)  loss = 1.8866e-05
# nt_epoch =   1290  elapsed = 02:23 (+01.0)  loss = 1.8565e-05
# nt_epoch =   1300  elapsed = 02:24 (+01.0)  loss = 1.8216e-05
# nt_epoch =   1310  elapsed = 02:25 (+01.0)  loss = 1.7944e-05
# nt_epoch =   1320  elapsed = 02:26 (+01.0)  loss = 1.7535e-05
# nt_epoch =   1330  elapsed = 02:27 (+01.0)  loss = 1.7148e-05
# nt_epoch =   1340  elapsed = 02:28 (+01.0)  loss = 1.6837e-05
# nt_epoch =   1350  elapsed = 02:29 (+01.0)  loss = 1.6507e-05
# nt_epoch =   1360  elapsed = 02:30 (+01.0)  loss = 1.6232e-05
# nt_epoch =   1370  elapsed = 02:31 (+01.0)  loss = 1.5980e-05
# nt_epoch =   1380  elapsed = 02:32 (+01.0)  loss = 1.5824e-05
# nt_epoch =   1390  elapsed = 02:33 (+01.0)  loss = 1.5556e-05
# nt_epoch =   1400  elapsed = 02:34 (+01.0)  loss = 1.5426e-05
# nt_epoch =   1410  elapsed = 02:35 (+01.0)  loss = 1.5221e-05
# nt_epoch =   1420  elapsed = 02:36 (+01.0)  loss = 1.5084e-05
# nt_epoch =   1430  elapsed = 02:37 (+01.0)  loss = 1.4978e-05
# nt_epoch =   1440  elapsed = 02:38 (+01.0)  loss = 1.4752e-05
# nt_epoch =   1450  elapsed = 02:39 (+01.0)  loss = 1.4545e-05
# nt_epoch =   1460  elapsed = 02:40 (+01.0)  loss = 1.4340e-05
# nt_epoch =   1470  elapsed = 02:41 (+00.9)  loss = 1.4126e-05
# nt_epoch =   1480  elapsed = 02:42 (+01.0)  loss = 1.4026e-05
# nt_epoch =   1490  elapsed = 02:43 (+01.0)  loss = 1.3896e-05
# nt_epoch =   1500  elapsed = 02:44 (+00.9)  loss = 1.3760e-05
# nt_epoch =   1510  elapsed = 02:45 (+01.0)  loss = 1.3614e-05
# nt_epoch =   1520  elapsed = 02:46 (+01.0)  loss = 1.3433e-05
# nt_epoch =   1530  elapsed = 02:48 (+01.0)  loss = 1.3325e-05
# nt_epoch =   1540  elapsed = 02:49 (+01.0)  loss = 1.3058e-05
# nt_epoch =   1550  elapsed = 02:50 (+01.0)  loss = 1.2837e-05
# nt_epoch =   1560  elapsed = 02:51 (+00.9)  loss = 1.2681e-05
# nt_epoch =   1570  elapsed = 02:52 (+01.0)  loss = 1.2554e-05
# nt_epoch =   1580  elapsed = 02:53 (+00.9)  loss = 1.2360e-05
# nt_epoch =   1590  elapsed = 02:54 (+01.0)  loss = 1.2199e-05
# nt_epoch =   1600  elapsed = 02:55 (+00.9)  loss = 1.2069e-05
# nt_epoch =   1610  elapsed = 02:56 (+01.0)  loss = 1.1931e-05
# nt_epoch =   1620  elapsed = 02:57 (+00.9)  loss = 1.1806e-05
# nt_epoch =   1630  elapsed = 02:58 (+01.0)  loss = 1.1696e-05
# nt_epoch =   1640  elapsed = 02:59 (+00.9)  loss = 1.1535e-05
# nt_epoch =   1650  elapsed = 03:00 (+01.0)  loss = 1.1421e-05
# nt_epoch =   3530  elapsed = 06:11 (+00.9)  loss = 1.8742e-06
# nt_epoch =   3540  elapsed = 06:12 (+01.0)  loss = 1.8658e-06
# nt_epoch =   3550  elapsed = 06:13 (+01.0)  loss = 1.8615e-06
# nt_epoch =   3560  elapsed = 06:14 (+01.0)  loss = 1.8533e-06
# nt_epoch =   3570  elapsed = 06:15 (+01.0)  loss = 1.8376e-06
# nt_epoch =   3580  elapsed = 06:16 (+00.9)  loss = 1.8227e-06
# nt_epoch =   3590  elapsed = 06:17 (+01.0)  loss = 1.8108e-06
# nt_epoch =   3600  elapsed = 06:18 (+01.0)  loss = 1.7963e-06
# nt_epoch =   3610  elapsed = 06:19 (+01.0)  loss = 1.7847e-06
# nt_epoch =   3620  elapsed = 06:20 (+01.0)  loss = 1.7746e-06
# nt_epoch =   3630  elapsed = 06:21 (+01.0)  loss = 1.7656e-06
# nt_epoch =   3640  elapsed = 06:22 (+01.0)  loss = 1.7569e-06
# nt_epoch =   3650  elapsed = 06:23 (+01.0)  loss = 1.7477e-06
# nt_epoch =   3660  elapsed = 06:24 (+01.0)  loss = 1.7427e-06
# nt_epoch =   3670  elapsed = 06:25 (+01.0)  loss = 1.7330e-06
# nt_epoch =   3680  elapsed = 06:26 (+01.0)  loss = 1.7320e-06
# nt_epoch =   3690  elapsed = 06:27 (+01.0)  loss = 1.7153e-06
# nt_epoch =   3700  elapsed = 06:28 (+00.9)  loss = 1.7017e-06
# nt_epoch =   3710  elapsed = 06:29 (+00.9)  loss = 1.6944e-06
# nt_epoch =   3720  elapsed = 06:30 (+00.9)  loss = 1.6860e-06
# nt_epoch =   3730  elapsed = 06:31 (+00.9)  loss = 1.6756e-06
# nt_epoch =   3740  elapsed = 06:32 (+00.9)  loss = 1.6615e-06
# nt_epoch =   3750  elapsed = 06:33 (+01.0)  loss = 1.6446e-06
# nt_epoch =   3760  elapsed = 06:34 (+01.0)  loss = 1.6369e-06
# nt_epoch =   3770  elapsed = 06:35 (+00.9)  loss = 1.6272e-06
# nt_epoch =   3780  elapsed = 06:36 (+00.9)  loss = 1.6176e-06
# nt_epoch =   3790  elapsed = 06:37 (+01.0)  loss = 1.6112e-06
# nt_epoch =   3800  elapsed = 06:38 (+00.9)  loss = 1.5956e-06
# nt_epoch =   3810  elapsed = 06:39 (+00.9)  loss = 1.5857e-06
# nt_epoch =   3820  elapsed = 06:40 (+01.0)  loss = 1.5775e-06
# nt_epoch =   3830  elapsed = 06:41 (+00.9)  loss = 1.5700e-06
# nt_epoch =   3840  elapsed = 06:42 (+01.0)  loss = 1.5620e-06
# nt_epoch =   3850  elapsed = 06:43 (+01.0)  loss = 1.5483e-06
# nt_epoch =   3860  elapsed = 06:44 (+00.9)  loss = 1.5408e-06
# nt_epoch =   3870  elapsed = 06:45 (+00.9)  loss = 1.5325e-06
# nt_epoch =   3880  elapsed = 06:46 (+00.9)  loss = 1.5259e-06
# nt_epoch =   3890  elapsed = 06:47 (+01.0)  loss = 1.5188e-06
# nt_epoch =   3900  elapsed = 06:48 (+00.9)  loss = 1.5076e-06
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 08:39 (+01.1)  loss = 5.1114e-01
# tf_epoch =     10  elapsed = 08:39 (+00.6)  loss = 3.1651e-01
# tf_epoch =     20  elapsed = 08:40 (+00.6)  loss = 1.7051e-01
# tf_epoch =     30  elapsed = 08:40 (+00.6)  loss = 1.1485e-01
# tf_epoch =     40  elapsed = 08:41 (+00.6)  loss = 9.6951e-02
# tf_epoch =     50  elapsed = 08:42 (+00.6)  loss = 8.4336e-02
# tf_epoch =     60  elapsed = 08:42 (+00.6)  loss = 7.3800e-02
# tf_epoch =     70  elapsed = 08:43 (+00.6)  loss = 5.7616e-02
# tf_epoch =     80  elapsed = 08:44 (+00.6)  loss = 3.8310e-02
# tf_epoch =     90  elapsed = 08:44 (+00.6)  loss = 3.2154e-02
# tf_epoch =    100  elapsed = 08:45 (+00.6)  loss = 2.9352e-02
# tf_epoch =    110  elapsed = 08:45 (+00.6)  loss = 2.6752e-02
# tf_epoch =    120  elapsed = 08:46 (+00.6)  loss = 3.6514e-02
# tf_epoch =    130  elapsed = 08:47 (+00.6)  loss = 3.1477e-02
# tf_epoch =    140  elapsed = 08:47 (+00.6)  loss = 2.6447e-02
# tf_epoch =    150  elapsed = 08:48 (+00.6)  loss = 2.5985e-02
# tf_epoch =    160  elapsed = 08:49 (+00.6)  loss = 2.3214e-02
# tf_epoch =    170  elapsed = 08:49 (+00.6)  loss = 2.2308e-02
# tf_epoch =    180  elapsed = 08:50 (+00.6)  loss = 2.1409e-02
# tf_epoch =    190  elapsed = 08:50 (+00.6)  loss = 1.1019e-01
# -- Starting LBFGS optimization --
# nt_epoch =     10  elapsed = 08:52 (+01.4)  loss = 2.3720e-02
# nt_epoch =     20  elapsed = 08:53 (+00.8)  loss = 2.1580e-02
# nt_epoch =     30  elapsed = 08:54 (+00.9)  loss = 2.0207e-02
# nt_epoch =     40  elapsed = 08:55 (+00.9)  loss = 1.9037e-02
# nt_epoch =     50  elapsed = 08:56 (+01.0)  loss = 1.7265e-02
# nt_epoch =     60  elapsed = 08:57 (+01.0)  loss = 1.4441e-02
# nt_epoch =     70  elapsed = 08:58 (+00.9)  loss = 1.3240e-02
# nt_epoch =     80  elapsed = 08:59 (+01.0)  loss = 1.2279e-02
# nt_epoch =     90  elapsed = 09:00 (+01.0)  loss = 1.1493e-02
# nt_epoch =    100  elapsed = 09:01 (+01.0)  loss = 1.0538e-02
# nt_epoch =    110  elapsed = 09:02 (+01.0)  loss = 9.5420e-03
# nt_epoch =    120  elapsed = 09:03 (+01.0)  loss = 8.4875e-03
# nt_epoch =    130  elapsed = 09:04 (+01.0)  loss = 7.4228e-03
# nt_epoch =    140  elapsed = 09:05 (+01.0)  loss = 6.0680e-03
# nt_epoch =    150  elapsed = 09:06 (+01.0)  loss = 5.0935e-03
# nt_epoch =    160  elapsed = 09:07 (+01.0)  loss = 4.6398e-03
# nt_epoch =    170  elapsed = 09:08 (+01.0)  loss = 3.8314e-03
# nt_epoch =    180  elapsed = 09:09 (+01.0)  loss = 3.5573e-03
# nt_epoch =    190  elapsed = 09:10 (+01.0)  loss = 3.2253e-03
# nt_epoch =    200  elapsed = 09:11 (+01.0)  loss = 2.8433e-03
# nt_epoch =    210  elapsed = 09:12 (+01.0)  loss = 2.6772e-03
# nt_epoch =    220  elapsed = 09:13 (+01.0)  loss = 2.3718e-03
# nt_epoch =    230  elapsed = 09:14 (+01.0)  loss = 1.9001e-03
# nt_epoch =    240  elapsed = 09:15 (+01.0)  loss = 1.6955e-03
# nt_epoch =    250  elapsed = 09:16 (+01.0)  loss = 1.4897e-03
# nt_epoch =    260  elapsed = 09:17 (+01.0)  loss = 1.3418e-03
# nt_epoch =    270  elapsed = 09:18 (+01.0)  loss = 1.1955e-03
# nt_epoch =    280  elapsed = 09:19 (+01.0)  loss = 1.1264e-03
# nt_epoch =    290  elapsed = 09:20 (+00.9)  loss = 1.0003e-03
# nt_epoch =    300  elapsed = 09:21 (+00.9)  loss = 9.1839e-04
# nt_epoch =    310  elapsed = 09:22 (+01.0)  loss = 8.6030e-04
# nt_epoch =    320  elapsed = 09:23 (+01.0)  loss = 8.2880e-04
# nt_epoch =    330  elapsed = 09:24 (+01.0)  loss = 7.7831e-04
# nt_epoch =    340  elapsed = 09:25 (+01.0)  loss = 7.2338e-04
# nt_epoch =    350  elapsed = 09:26 (+01.0)  loss = 6.6174e-04
# nt_epoch =    360  elapsed = 09:27 (+01.0)  loss = 6.2186e-04
# nt_epoch =    370  elapsed = 09:28 (+01.0)  loss = 5.8745e-04
# nt_epoch =    380  elapsed = 09:29 (+01.0)  loss = 5.6776e-04
# nt_epoch =    390  elapsed = 09:30 (+01.0)  loss = 5.5065e-04
# nt_epoch =    400  elapsed = 09:31 (+01.0)  loss = 5.0514e-04
# nt_epoch =    410  elapsed = 09:32 (+01.0)  loss = 4.6357e-04
# nt_epoch =    420  elapsed = 09:33 (+01.0)  loss = 4.4265e-04
# nt_epoch =    430  elapsed = 09:34 (+01.0)  loss = 4.2868e-04
# nt_epoch =    440  elapsed = 09:35 (+01.0)  loss = 4.1536e-04
# nt_epoch =    450  elapsed = 09:36 (+01.0)  loss = 4.0289e-04
# nt_epoch =    460  elapsed = 09:37 (+01.0)  loss = 3.9421e-04
# nt_epoch =    470  elapsed = 09:38 (+01.0)  loss = 3.8066e-04
# nt_epoch =    480  elapsed = 09:39 (+01.0)  loss = 3.5933e-04
# nt_epoch =    490  elapsed = 09:40 (+01.0)  loss = 3.4994e-04
# nt_epoch =    500  elapsed = 09:41 (+01.0)  loss = 3.3460e-04
# nt_epoch =    510  elapsed = 09:42 (+01.0)  loss = 3.2504e-04
# nt_epoch =    520  elapsed = 09:43 (+01.0)  loss = 3.1034e-04
# nt_epoch =    530  elapsed = 09:44 (+01.0)  loss = 2.9856e-04
# nt_epoch =    540  elapsed = 09:45 (+01.0)  loss = 2.9223e-04
# nt_epoch =    550  elapsed = 09:47 (+01.0)  loss = 2.7731e-04
# nt_epoch =    560  elapsed = 09:48 (+01.0)  loss = 2.6072e-04
# nt_epoch =    570  elapsed = 09:49 (+01.0)  loss = 2.3938e-04
# nt_epoch =    580  elapsed = 09:50 (+01.0)  loss = 2.2687e-04
# nt_epoch =    590  elapsed = 09:51 (+00.9)  loss = 2.1647e-04
# nt_epoch =    600  elapsed = 09:52 (+01.0)  loss = 2.0932e-04
# nt_epoch =    610  elapsed = 09:53 (+01.0)  loss = 2.0392e-04
# nt_epoch =    620  elapsed = 09:54 (+00.9)  loss = 1.9555e-04
# nt_epoch =    630  elapsed = 09:55 (+01.0)  loss = 1.8994e-04
# nt_epoch =    640  elapsed = 09:56 (+01.0)  loss = 1.8550e-04
# nt_epoch =    650  elapsed = 09:57 (+00.9)  loss = 1.8038e-04
# nt_epoch =    660  elapsed = 09:58 (+01.0)  loss = 1.7447e-04
# nt_epoch =    670  elapsed = 09:59 (+01.0)  loss = 1.6714e-04
# nt_epoch =    680  elapsed = 10:00 (+01.1)  loss = 1.6011e-04
# nt_epoch =    690  elapsed = 10:01 (+01.0)  loss = 1.5708e-04
# nt_epoch =    700  elapsed = 10:02 (+01.0)  loss = 1.5381e-04
# nt_epoch =    710  elapsed = 10:03 (+01.0)  loss = 1.5044e-04
# nt_epoch =    720  elapsed = 10:04 (+01.0)  loss = 1.4738e-04
# nt_epoch =    730  elapsed = 10:05 (+01.0)  loss = 1.4281e-04
# nt_epoch =    740  elapsed = 10:06 (+01.0)  loss = 1.4031e-04
# nt_epoch =    750  elapsed = 10:07 (+01.0)  loss = 1.3509e-04
# nt_epoch =    760  elapsed = 10:08 (+01.0)  loss = 1.3130e-04
# nt_epoch =    770  elapsed = 10:09 (+01.0)  loss = 1.2999e-04
# nt_epoch =    780  elapsed = 10:10 (+01.0)  loss = 1.2508e-04
# nt_epoch =    790  elapsed = 10:11 (+01.0)  loss = 1.2261e-04
# nt_epoch =    800  elapsed = 10:12 (+01.0)  loss = 1.2045e-04
# nt_epoch =    810  elapsed = 10:13 (+00.9)  loss = 1.1916e-04
# nt_epoch =    820  elapsed = 10:14 (+00.9)  loss = 1.1784e-04
# nt_epoch =    830  elapsed = 10:15 (+01.0)  loss = 1.1509e-04
# nt_epoch =    840  elapsed = 10:16 (+01.0)  loss = 1.1331e-04
# nt_epoch =    850  elapsed = 10:17 (+00.9)  loss = 1.1159e-04
# nt_epoch =    860  elapsed = 10:18 (+00.9)  loss = 1.0950e-04
# nt_epoch =    870  elapsed = 10:19 (+01.0)  loss = 1.0653e-04
# nt_epoch =    880  elapsed = 10:20 (+01.0)  loss = 1.0455e-04
# nt_epoch =    890  elapsed = 10:22 (+01.0)  loss = 1.0274e-04
# nt_epoch =    900  elapsed = 10:23 (+01.0)  loss = 9.9739e-05
# nt_epoch =    910  elapsed = 10:24 (+01.0)  loss = 9.7826e-05
# nt_epoch =    920  elapsed = 10:25 (+01.0)  loss = 9.5886e-05
# nt_epoch =    930  elapsed = 10:26 (+01.0)  loss = 9.3675e-05
# nt_epoch =    940  elapsed = 10:27 (+01.0)  loss = 9.1151e-05
# nt_epoch =    950  elapsed = 10:28 (+01.0)  loss = 8.8112e-05
# nt_epoch =    960  elapsed = 10:29 (+01.0)  loss = 8.3534e-05
# nt_epoch =    970  elapsed = 10:30 (+01.0)  loss = 8.1916e-05
# nt_epoch =    980  elapsed = 10:31 (+01.0)  loss = 8.0197e-05
# nt_epoch =   1360  elapsed = 11:09 (+01.0)  loss = 4.2004e-05
# nt_epoch =   1370  elapsed = 11:10 (+01.0)  loss = 4.1662e-05
# nt_epoch =   1380  elapsed = 11:11 (+01.0)  loss = 4.1060e-05
# nt_epoch =   1390  elapsed = 11:12 (+01.0)  loss = 4.0652e-05
# nt_epoch =   1400  elapsed = 11:13 (+01.0)  loss = 4.0285e-05
# nt_epoch =   1410  elapsed = 11:14 (+00.9)  loss = 3.9973e-05
# nt_epoch =   1420  elapsed = 11:15 (+01.0)  loss = 3.9577e-05
# nt_epoch =   1430  elapsed = 11:16 (+01.0)  loss = 3.8914e-05
# nt_epoch =   1440  elapsed = 11:17 (+01.0)  loss = 3.8614e-05
# nt_epoch =   1450  elapsed = 11:18 (+01.0)  loss = 3.8250e-05
# nt_epoch =   1460  elapsed = 11:19 (+01.0)  loss = 3.7977e-05
# nt_epoch =   1470  elapsed = 11:20 (+01.0)  loss = 3.7532e-05
# nt_epoch =   1480  elapsed = 11:21 (+01.0)  loss = 3.7112e-05
# nt_epoch =   1490  elapsed = 11:22 (+01.0)  loss = 3.6517e-05
# nt_epoch =   1500  elapsed = 11:23 (+01.0)  loss = 3.5869e-05
# nt_epoch =   1510  elapsed = 11:24 (+01.0)  loss = 3.5246e-05
# nt_epoch =   1520  elapsed = 11:25 (+01.0)  loss = 3.4507e-05
# nt_epoch =   1530  elapsed = 11:26 (+01.0)  loss = 3.4142e-05
# nt_epoch =   1540  elapsed = 11:27 (+01.0)  loss = 3.3401e-05
# nt_epoch =   1550  elapsed = 11:28 (+00.9)  loss = 3.2896e-05
# nt_epoch =   1560  elapsed = 11:29 (+01.0)  loss = 3.2551e-05
# nt_epoch =   1570  elapsed = 11:30 (+00.9)  loss = 3.2179e-05
# nt_epoch =   1580  elapsed = 11:31 (+01.0)  loss = 3.1950e-05
# nt_epoch =   1590  elapsed = 11:32 (+01.0)  loss = 3.1376e-05
# nt_epoch =   1600  elapsed = 11:33 (+01.0)  loss = 3.0884e-05
# nt_epoch =   1610  elapsed = 11:34 (+01.0)  loss = 3.0678e-05
# nt_epoch =   1620  elapsed = 11:35 (+01.0)  loss = 3.0139e-05
# nt_epoch =   1630  elapsed = 11:36 (+00.9)  loss = 2.9848e-05
# nt_epoch =   1640  elapsed = 11:37 (+01.0)  loss = 2.9473e-05
# nt_epoch =   1650  elapsed = 11:38 (+01.0)  loss = 2.9247e-05
# nt_epoch =   1660  elapsed = 11:39 (+01.0)  loss = 2.8934e-05
# nt_epoch =   1670  elapsed = 11:40 (+01.0)  loss = 2.8801e-05
# nt_epoch =   1680  elapsed = 11:41 (+01.0)  loss = 2.8260e-05
# nt_epoch =   1690  elapsed = 11:42 (+01.0)  loss = 2.8429e-05
# nt_epoch =   1700  elapsed = 11:43 (+01.0)  loss = 2.7718e-05
# nt_epoch =   1710  elapsed = 11:44 (+01.0)  loss = 2.7534e-05
# nt_epoch =   1720  elapsed = 11:45 (+01.0)  loss = 2.7345e-05
# nt_epoch =   1730  elapsed = 11:46 (+01.0)  loss = 2.7144e-05
# nt_epoch =   4970  elapsed = 17:14 (+01.0)  loss = 2.9182e-06
# nt_epoch =   4980  elapsed = 17:15 (+00.9)  loss = 2.9179e-06
# nt_epoch =   4990  elapsed = 17:16 (+00.9)  loss = 2.9176e-06
# ==================
# Training finished (epoch 5200): duration = 17:17  error = 7.3984e-05
# l1:  0.999815178361342
# l2:  0.0031796236676157326
# l1_noise:  1.0000308566936478
# l2_noise:  0.003183471641799456

# %%
#%% PLOTTING
plot_ide_cont_results(X_star, u_pred, X_u_train, u_train,
        Exact_u, X, T, x, t, lambda_1_pred, lambda_1_pred_noise, lambda_2_pred, lambda_2_pred_noise)

# %% [markdown]
# What if I apply the inception concept to: 1) increase the training speed and 2) solve the vanish gradients problem?

# %% [markdown]
# # WIDER NN

# %%
import sys
import json
import os
import tensorflow as tf
import numpy as np
import tensorflow_probability as tfp

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# HYPER PARAMETERS

hp = {}
# Data size on the solution u
hp["N_u"] = 2000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 50, 50, 50, 50, 50, 50, 50, 50, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 200
hp["tf_lr"] = 0.01
hp["tf_b1"] = 0.9
hp["tf_eps"] = None
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 5000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 10

#%% DEFINING THE MODEL

class BurgersInformedNN(NeuralNetwork):
    def __init__(self, hp, logger, ub, lb):
        super().__init__(hp, logger, ub, lb)

        # Defining the two additional trainable variables for identification
        self.lambda_1 = tf.Variable([0.0], dtype=self.dtype)
        self.lambda_2 = tf.Variable([-6.0], dtype=self.dtype)

  # The actual PINN
    def f_model(self, X_u):
      l1, l2 = self.get_params()
    # Separating the collocation coordinates
      x_f = tf.convert_to_tensor(X_u[:, 0:1], dtype=self.dtype)
      t_f = tf.convert_to_tensor(X_u[:, 1:2], dtype=self.dtype)

      # Using the new GradientTape paradigm of TF2.0,
      # which keeps track of operations to get the gradient at runtime
      with tf.GradientTape(persistent=True) as tape:
        # Watching the two inputs we’ll need later, x and t
        tape.watch(x_f)
        tape.watch(t_f)
        # Packing together the inputs
        X_f = tf.stack([x_f[:,0], t_f[:,0]], axis=1)


        # Getting the prediction
        u = self.model(X_f)
        # Deriving INSIDE the tape (since we’ll need the x derivative of this later, u_xx)
        u_x = tape.gradient(u, x_f)

      # Getting the other derivatives
      u_xx = tape.gradient(u_x, x_f)
      u_t = tape.gradient(u, t_f)

      # Letting the tape go
      del tape

      # Buidling the PINNs
      return u_t + l1*u*u_x - l2*u_xx

  # Defining custom loss
    def loss(self, u, u_pred):
        f_pred = self.f_model(self.X_u)
        return tf.reduce_mean(tf.square(u - u_pred)) + \
              tf.reduce_mean(tf.square(f_pred))

    def wrap_training_variables(self):
      var = self.model.trainable_variables
      var.extend([self.lambda_1, self.lambda_2])
      return var

    def get_weights(self):
        w = super().get_weights(convert_to_tensor=False)
        w.extend(self.lambda_1.numpy())
        w.extend(self.lambda_2.numpy())
        return tf.convert_to_tensor(w, dtype=self.dtype)

    def set_weights(self, w):
      super().set_weights(w)
      self.lambda_1.assign([w[-2]])
      self.lambda_2.assign([w[-1]])

    def get_params(self, numpy=False):
      l1 = self.lambda_1
      l2 = tf.exp(self.lambda_2)
      if numpy:
          return l1.numpy()[0], l2.numpy()[0]
      return l1, l2

    def fit(self, X_u, u):
      self.X_u =  tf.convert_to_tensor(X_u, dtype=self.dtype)
      super().fit(X_u, u)

    def predict(self, X_star):
      u_star = self.model(X_star)
      f_star = self.f_model(X_star)
      return u_star.numpy(), f_star.numpy()

# %% TRAINING THE MODEL


# Getting the data
path = os.path.join("/content/drive/MyDrive/PINNs-TF2.0/1d-burgers/data", "burgers_shock.mat")
x, t, X, T, Exact_u, X_star, u_star, \
        X_u_train, u_train, ub, lb = prep_data(path, hp["N_u"], noise=0.0)
lambdas_star = (1.0, 0.01/np.pi)

# Creating the model
logger = Logger(hp)
pinn = BurgersInformedNN(hp, logger, ub, lb)

# Defining the error function for the logger and training
def error():
  l1, l2 = pinn.get_params(numpy=True)
  l1_star, l2_star = lambdas_star
  error_lambda_1 = np.abs(l1 - l1_star) / l1_star
  error_lambda_2 = np.abs(l2 - l2_star) / l2_star
  return (error_lambda_1 + error_lambda_2) / 2

logger.set_error_fn(error)
pinn.fit(X_u_train, u_train)

# Getting the model predictions, from the same (x,t) that the predictions were previously gotten from
u_pred, f_pred = pinn.predict(X_star)
lambda_1_pred, lambda_2_pred = pinn.get_params(numpy=True)

# Noise case
x, t, X, T, Exact_u, X_star, u_star, \
        X_u_train, u_train, ub, lb = prep_data(path, hp["N_u"], noise=0.01)
pinn = BurgersInformedNN(hp, logger, ub, lb)
pinn.fit(X_u_train, u_train)
lambda_1_pred_noise, lambda_2_pred_noise = pinn.get_params(numpy=True)

print("l1: ", lambda_1_pred)
print("l2: ", lambda_2_pred)
print("l1_noise: ", lambda_1_pred_noise)
print("l2_noise: ", lambda_2_pred_noise)
# Out:
# Hyperparameters:
# {
#   "N_u": 2000,
#   "layers": [
#     2,
#     50,
#     50,
#     50,
#     50,
#     50,
#     50,
#     50,
#     50,
#     1
#   ],
#   "tf_epochs": 200,
#   "tf_lr": 0.01,
#   "tf_b1": 0.9,
#   "tf_eps": null,
#   "nt_epochs": 5000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: True
#
# Training started
# ================
# -- Starting Adam optimization --
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# tf_epoch =      0  elapsed = 00:00 (+00.1)  loss = 3.8720e-01
# tf_epoch =     10  elapsed = 00:00 (+00.4)  loss = 4.0536e-01
# tf_epoch =     20  elapsed = 00:00 (+00.4)  loss = 1.8286e-01
# tf_epoch =     30  elapsed = 00:01 (+00.3)  loss = 7.7974e-02
# tf_epoch =     40  elapsed = 00:01 (+00.4)  loss = 6.3191e-02
# tf_epoch =     50  elapsed = 00:02 (+00.3)  loss = 4.7451e-02
# tf_epoch =     60  elapsed = 00:02 (+00.4)  loss = 3.8800e-02
# tf_epoch =     70  elapsed = 00:02 (+00.4)  loss = 3.3273e-02
# tf_epoch =     80  elapsed = 00:03 (+00.3)  loss = 3.0351e-02
# tf_epoch =     90  elapsed = 00:03 (+00.3)  loss = 2.8643e-02
# tf_epoch =    100  elapsed = 00:04 (+00.3)  loss = 2.7510e-02
# tf_epoch =    110  elapsed = 00:04 (+00.4)  loss = 2.6508e-02
# tf_epoch =    120  elapsed = 00:04 (+00.3)  loss = 2.5576e-02
# tf_epoch =    130  elapsed = 00:05 (+00.4)  loss = 2.4700e-02
# tf_epoch =    140  elapsed = 00:05 (+00.4)  loss = 2.3875e-02
# tf_epoch =    150  elapsed = 00:06 (+00.3)  loss = 2.3087e-02
# tf_epoch =    160  elapsed = 00:06 (+00.4)  loss = 2.2329e-02
# tf_epoch =    170  elapsed = 00:06 (+00.3)  loss = 2.1596e-02
# tf_epoch =    180  elapsed = 00:07 (+00.3)  loss = 2.0878e-02
# tf_epoch =    190  elapsed = 00:07 (+00.4)  loss = 2.0168e-02
# -- Starting LBFGS optimization --
# nt_epoch =     10  elapsed = 00:08 (+00.9)  loss = 1.8490e-02
# nt_epoch =     20  elapsed = 00:09 (+00.5)  loss = 1.5673e-02
# nt_epoch =     30  elapsed = 00:09 (+00.6)  loss = 1.2789e-02
# nt_epoch =     40  elapsed = 00:10 (+00.6)  loss = 1.0493e-02
# nt_epoch =     50  elapsed = 00:11 (+00.7)  loss = 8.7572e-03
# nt_epoch =     60  elapsed = 00:12 (+00.7)  loss = 7.6170e-03
# nt_epoch =     70  elapsed = 00:12 (+00.6)  loss = 6.2939e-03
# nt_epoch =     80  elapsed = 00:13 (+00.7)  loss = 5.6054e-03
# nt_epoch =     90  elapsed = 00:14 (+00.7)  loss = 4.8888e-03
# nt_epoch =    100  elapsed = 00:14 (+00.7)  loss = 3.9939e-03
# nt_epoch =    110  elapsed = 00:15 (+00.7)  loss = 3.4752e-03
# nt_epoch =    120  elapsed = 00:16 (+00.6)  loss = 3.0305e-03
# nt_epoch =    130  elapsed = 00:16 (+00.7)  loss = 2.7079e-03
# nt_epoch =    140  elapsed = 00:17 (+00.7)  loss = 2.3709e-03
# nt_epoch =    150  elapsed = 00:18 (+00.7)  loss = 2.0350e-03
# nt_epoch =    160  elapsed = 00:19 (+00.7)  loss = 1.6656e-03
# nt_epoch =    170  elapsed = 00:19 (+00.7)  loss = 1.5357e-03
# nt_epoch =    180  elapsed = 00:20 (+00.6)  loss = 1.3559e-03
# nt_epoch =    190  elapsed = 00:21 (+00.7)  loss = 1.2318e-03
# nt_epoch =    200  elapsed = 00:21 (+00.7)  loss = 1.0830e-03
# nt_epoch =    210  elapsed = 00:22 (+00.6)  loss = 1.0233e-03
# nt_epoch =    220  elapsed = 00:23 (+00.7)  loss = 9.4450e-04
# nt_epoch =    230  elapsed = 00:24 (+00.7)  loss = 8.6532e-04
# nt_epoch =    240  elapsed = 00:24 (+00.6)  loss = 8.2366e-04
# nt_epoch =    250  elapsed = 00:25 (+00.6)  loss = 7.6592e-04
# nt_epoch =    260  elapsed = 00:26 (+00.7)  loss = 7.2173e-04
# nt_epoch =    270  elapsed = 00:26 (+00.7)  loss = 6.8708e-04
# nt_epoch =    280  elapsed = 00:27 (+00.7)  loss = 6.4901e-04
# nt_epoch =    290  elapsed = 00:28 (+00.6)  loss = 6.1147e-04
# nt_epoch =    300  elapsed = 00:28 (+00.7)  loss = 5.7424e-04
# nt_epoch =    310  elapsed = 00:29 (+00.7)  loss = 5.3873e-04
# nt_epoch =    320  elapsed = 00:30 (+00.7)  loss = 5.1814e-04
# nt_epoch =    330  elapsed = 00:31 (+00.7)  loss = 4.8191e-04
# nt_epoch =    340  elapsed = 00:31 (+00.6)  loss = 4.6408e-04
# nt_epoch =    350  elapsed = 00:32 (+00.6)  loss = 4.4339e-04
# nt_epoch =    360  elapsed = 00:33 (+00.7)  loss = 4.2705e-04
# nt_epoch =    370  elapsed = 00:33 (+00.7)  loss = 4.1235e-04
# nt_epoch =    380  elapsed = 00:34 (+00.6)  loss = 3.8598e-04
# nt_epoch =    390  elapsed = 00:35 (+00.7)  loss = 3.7271e-04
# nt_epoch =    400  elapsed = 00:36 (+00.6)  loss = 3.6096e-04
# nt_epoch =    410  elapsed = 00:36 (+00.6)  loss = 3.4730e-04
# nt_epoch =    420  elapsed = 00:37 (+00.7)  loss = 3.3275e-04
# nt_epoch =    430  elapsed = 00:38 (+00.7)  loss = 3.1713e-04
# nt_epoch =    440  elapsed = 00:38 (+00.6)  loss = 3.0689e-04
# nt_epoch =    450  elapsed = 00:39 (+00.7)  loss = 3.0001e-04
# nt_epoch =    460  elapsed = 00:40 (+00.6)  loss = 2.9040e-04
# nt_epoch =    470  elapsed = 00:40 (+00.7)  loss = 2.8063e-04
# nt_epoch =    480  elapsed = 00:41 (+00.6)  loss = 2.6815e-04
# nt_epoch =    490  elapsed = 00:42 (+00.7)  loss = 2.5754e-04
# nt_epoch =    500  elapsed = 00:43 (+00.7)  loss = 2.5050e-04
# nt_epoch =    510  elapsed = 00:43 (+00.6)  loss = 2.4083e-04
# nt_epoch =    520  elapsed = 00:44 (+00.7)  loss = 2.3241e-04
# nt_epoch =    530  elapsed = 00:45 (+00.7)  loss = 2.2319e-04
# nt_epoch =    540  elapsed = 00:45 (+00.7)  loss = 2.1844e-04
# nt_epoch =    550  elapsed = 00:46 (+00.7)  loss = 2.1110e-04
# nt_epoch =    560  elapsed = 00:47 (+00.7)  loss = 2.0324e-04
# nt_epoch =    570  elapsed = 00:47 (+00.7)  loss = 1.9525e-04
# nt_epoch =    580  elapsed = 00:48 (+00.6)  loss = 1.7865e-04
# nt_epoch =    590  elapsed = 00:49 (+00.7)  loss = 1.6993e-04
# nt_epoch =    600  elapsed = 00:50 (+00.7)  loss = 1.6200e-04
# nt_epoch =    610  elapsed = 00:50 (+00.6)  loss = 1.5450e-04
# nt_epoch =    620  elapsed = 00:51 (+00.6)  loss = 1.4833e-04
# nt_epoch =    630  elapsed = 00:52 (+00.7)  loss = 1.4129e-04
# nt_epoch =    640  elapsed = 00:52 (+00.6)  loss = 1.3442e-04
# nt_epoch =    650  elapsed = 00:53 (+00.7)  loss = 1.2915e-04
# nt_epoch =    660  elapsed = 00:54 (+00.6)  loss = 1.2448e-04
# nt_epoch =    670  elapsed = 00:55 (+00.7)  loss = 1.2260e-04
# nt_epoch =    680  elapsed = 00:55 (+00.7)  loss = 1.1467e-04
# nt_epoch =    690  elapsed = 00:56 (+00.7)  loss = 1.0902e-04
# nt_epoch =    700  elapsed = 00:57 (+00.7)  loss = 1.0446e-04
# nt_epoch =    710  elapsed = 00:57 (+00.6)  loss = 1.0020e-04
# nt_epoch =    720  elapsed = 00:58 (+00.7)  loss = 9.5850e-05
# nt_epoch =    730  elapsed = 00:59 (+00.7)  loss = 9.2635e-05
# nt_epoch =    740  elapsed = 01:00 (+00.7)  loss = 8.8585e-05
# nt_epoch =    750  elapsed = 01:00 (+00.6)  loss = 8.5032e-05
# nt_epoch =    760  elapsed = 01:01 (+00.7)  loss = 8.1882e-05
# nt_epoch =    770  elapsed = 01:02 (+00.6)  loss = 7.7264e-05
# nt_epoch =    780  elapsed = 01:02 (+00.7)  loss = 7.2338e-05
# nt_epoch =    790  elapsed = 01:03 (+00.7)  loss = 6.8992e-05
# nt_epoch =    800  elapsed = 01:04 (+00.7)  loss = 6.6655e-05
# nt_epoch =    810  elapsed = 01:04 (+00.7)  loss = 6.3005e-05
# nt_epoch =    820  elapsed = 01:05 (+00.7)  loss = 6.0924e-05
# nt_epoch =    830  elapsed = 01:06 (+00.7)  loss = 5.9219e-05
# nt_epoch =    840  elapsed = 01:07 (+00.7)  loss = 5.7077e-05
# nt_epoch =    850  elapsed = 01:07 (+00.7)  loss = 5.4068e-05
# nt_epoch =    860  elapsed = 01:08 (+00.7)  loss = 5.2156e-05
# nt_epoch =    870  elapsed = 01:09 (+00.7)  loss = 5.0596e-05
# nt_epoch =    880  elapsed = 01:10 (+00.7)  loss = 4.9623e-05
# nt_epoch =    890  elapsed = 01:10 (+00.7)  loss = 4.8186e-05
# nt_epoch =    900  elapsed = 01:11 (+00.7)  loss = 4.6539e-05
# nt_epoch =    910  elapsed = 01:12 (+00.7)  loss = 4.5623e-05
# nt_epoch =    920  elapsed = 01:12 (+00.7)  loss = 4.4167e-05
# nt_epoch =    930  elapsed = 01:13 (+00.7)  loss = 4.3506e-05
# nt_epoch =    940  elapsed = 01:14 (+00.7)  loss = 4.2051e-05
# nt_epoch =    950  elapsed = 01:15 (+00.6)  loss = 4.0899e-05
# nt_epoch =    960  elapsed = 01:15 (+00.7)  loss = 3.9573e-05
# nt_epoch =    970  elapsed = 01:16 (+00.7)  loss = 3.7760e-05
# nt_epoch =    980  elapsed = 01:17 (+00.7)  loss = 3.6670e-05
# nt_epoch =    990  elapsed = 01:17 (+00.6)  loss = 3.5968e-05
# nt_epoch =   1000  elapsed = 01:18 (+00.6)  loss = 3.5093e-05
# nt_epoch =   1010  elapsed = 01:19 (+00.7)  loss = 3.4343e-05
# nt_epoch =   1020  elapsed = 01:19 (+00.7)  loss = 3.3460e-05
# nt_epoch =   1030  elapsed = 01:20 (+00.7)  loss = 3.2768e-05
# nt_epoch =   1040  elapsed = 01:21 (+00.7)  loss = 3.2079e-05
# nt_epoch =   1050  elapsed = 01:22 (+00.7)  loss = 3.1372e-05
# nt_epoch =   1060  elapsed = 01:22 (+00.7)  loss = 3.0748e-05
# nt_epoch =   1070  elapsed = 01:23 (+00.6)  loss = 3.0135e-05
# nt_epoch =   1080  elapsed = 01:24 (+00.6)  loss = 2.9434e-05
# nt_epoch =   1090  elapsed = 01:24 (+00.7)  loss = 2.8699e-05
# nt_epoch =   1100  elapsed = 01:25 (+00.7)  loss = 2.8004e-05
# nt_epoch =   1110  elapsed = 01:26 (+00.7)  loss = 2.7305e-05
# nt_epoch =   1120  elapsed = 01:27 (+00.7)  loss = 2.6643e-05
# nt_epoch =   1130  elapsed = 01:27 (+00.7)  loss = 2.6040e-05
# nt_epoch =   1140  elapsed = 01:28 (+00.6)  loss = 2.5461e-05
# nt_epoch =   1150  elapsed = 01:29 (+00.7)  loss = 2.4706e-05
# nt_epoch =   1160  elapsed = 01:29 (+00.7)  loss = 2.4006e-05
# nt_epoch =   1170  elapsed = 01:30 (+00.7)  loss = 2.3111e-05
# nt_epoch =   1180  elapsed = 01:31 (+00.7)  loss = 2.1831e-05
# nt_epoch =   1190  elapsed = 01:31 (+00.7)  loss = 2.1277e-05
# nt_epoch =   1200  elapsed = 01:32 (+00.7)  loss = 2.0529e-05
# nt_epoch =   1210  elapsed = 01:33 (+00.7)  loss = 2.0079e-05
# nt_epoch =   1220  elapsed = 01:34 (+00.7)  loss = 1.9585e-05
# nt_epoch =   1230  elapsed = 01:34 (+00.7)  loss = 1.8943e-05
# nt_epoch =   1240  elapsed = 01:35 (+00.7)  loss = 1.8615e-05
# nt_epoch =   1250  elapsed = 01:36 (+00.6)  loss = 1.8099e-05
# nt_epoch =   1260  elapsed = 01:36 (+00.7)  loss = 1.7671e-05
# nt_epoch =   1270  elapsed = 01:37 (+00.7)  loss = 1.7376e-05
# nt_epoch =   1280  elapsed = 01:38 (+00.6)  loss = 1.7252e-05
# nt_epoch =   1290  elapsed = 01:39 (+00.7)  loss = 1.6632e-05
# nt_epoch =   1300  elapsed = 01:39 (+00.7)  loss = 1.6366e-05
# nt_epoch =   1310  elapsed = 01:40 (+00.6)  loss = 1.6085e-05
# nt_epoch =   1320  elapsed = 01:41 (+00.7)  loss = 1.5725e-05
# nt_epoch =   1330  elapsed = 01:41 (+00.7)  loss = 1.5425e-05
# nt_epoch =   1340  elapsed = 01:42 (+00.6)  loss = 1.5233e-05
# nt_epoch =   1350  elapsed = 01:43 (+00.7)  loss = 1.5045e-05
# nt_epoch =   1360  elapsed = 01:44 (+00.7)  loss = 1.4648e-05
# nt_epoch =   1370  elapsed = 01:44 (+00.7)  loss = 1.4309e-05
# nt_epoch =   1380  elapsed = 01:45 (+00.7)  loss = 1.4014e-05
# nt_epoch =   1390  elapsed = 01:46 (+00.7)  loss = 1.3554e-05
# nt_epoch =   1400  elapsed = 01:46 (+00.7)  loss = 1.3147e-05
# nt_epoch =   1410  elapsed = 01:47 (+00.7)  loss = 1.2421e-05
# nt_epoch =   1420  elapsed = 01:48 (+00.7)  loss = 1.2142e-05
# nt_epoch =   1430  elapsed = 01:49 (+00.7)  loss = 1.1988e-05
# nt_epoch =   1440  elapsed = 01:49 (+00.7)  loss = 1.1761e-05
# nt_epoch =   1450  elapsed = 01:50 (+00.7)  loss = 1.1573e-05
# nt_epoch =   1460  elapsed = 01:51 (+00.7)  loss = 1.1438e-05
# nt_epoch =   1470  elapsed = 01:51 (+00.7)  loss = 1.1190e-05
# nt_epoch =   1480  elapsed = 01:52 (+00.7)  loss = 1.1099e-05
# nt_epoch =   1490  elapsed = 01:53 (+00.7)  loss = 1.0920e-05
# nt_epoch =   1500  elapsed = 01:54 (+00.7)  loss = 1.0848e-05
# nt_epoch =   1510  elapsed = 01:54 (+00.7)  loss = 1.0555e-05
# nt_epoch =   1520  elapsed = 01:55 (+00.7)  loss = 1.0343e-05
# nt_epoch =   1530  elapsed = 01:56 (+00.6)  loss = 1.0169e-05
# nt_epoch =   1540  elapsed = 01:56 (+00.7)  loss = 9.9826e-06
# nt_epoch =   1550  elapsed = 01:57 (+00.7)  loss = 9.7673e-06
# nt_epoch =   1560  elapsed = 01:58 (+00.7)  loss = 9.6617e-06
# nt_epoch =   1570  elapsed = 01:59 (+00.7)  loss = 9.5023e-06
# nt_epoch =   1580  elapsed = 01:59 (+00.6)  loss = 9.3142e-06
# nt_epoch =   1590  elapsed = 02:00 (+00.7)  loss = 9.1208e-06
# nt_epoch =   1600  elapsed = 02:01 (+00.7)  loss = 8.9336e-06
# nt_epoch =   1610  elapsed = 02:01 (+00.7)  loss = 8.8517e-06
# nt_epoch =   1620  elapsed = 02:02 (+00.6)  loss = 8.7254e-06
# nt_epoch =   1630  elapsed = 02:03 (+00.7)  loss = 8.5895e-06
# nt_epoch =   1640  elapsed = 02:04 (+00.6)  loss = 8.5055e-06
# nt_epoch =   1650  elapsed = 02:04 (+00.6)  loss = 8.4180e-06
# nt_epoch =   1660  elapsed = 02:05 (+00.7)  loss = 8.3372e-06
# nt_epoch =   1670  elapsed = 02:06 (+00.7)  loss = 8.2353e-06
# nt_epoch =   1680  elapsed = 02:06 (+00.7)  loss = 8.1321e-06
# nt_epoch =   1690  elapsed = 02:07 (+00.7)  loss = 8.0425e-06
# nt_epoch =   1700  elapsed = 02:08 (+00.6)  loss = 7.9743e-06
# nt_epoch =   1710  elapsed = 02:09 (+00.7)  loss = 7.9239e-06
# nt_epoch =   1720  elapsed = 02:09 (+00.7)  loss = 7.9544e-06
# nt_epoch =   1730  elapsed = 02:10 (+00.7)  loss = 7.7828e-06
# nt_epoch =   1740  elapsed = 02:11 (+00.7)  loss = 7.6544e-06
# nt_epoch =   1750  elapsed = 02:11 (+00.7)  loss = 7.5425e-06
# nt_epoch =   1760  elapsed = 02:12 (+00.7)  loss = 7.3592e-06
# nt_epoch =   1770  elapsed = 02:13 (+00.6)  loss = 7.2615e-06
# nt_epoch =   1780  elapsed = 02:13 (+00.7)  loss = 7.1461e-06
# nt_epoch =   1790  elapsed = 02:14 (+00.7)  loss = 7.0608e-06
# nt_epoch =   1800  elapsed = 02:15 (+00.6)  loss = 6.8798e-06
# nt_epoch =   1810  elapsed = 02:16 (+00.7)  loss = 6.7488e-06
# nt_epoch =   1820  elapsed = 02:16 (+00.6)  loss = 6.6288e-06
# nt_epoch =   1830  elapsed = 02:17 (+00.6)  loss = 6.5629e-06
# nt_epoch =   1840  elapsed = 02:18 (+00.6)  loss = 6.4920e-06
# nt_epoch =   1850  elapsed = 02:18 (+00.6)  loss = 6.4129e-06
# nt_epoch =   1860  elapsed = 02:19 (+00.7)  loss = 6.3377e-06
# nt_epoch =   3370  elapsed = 04:07 (+00.7)  loss = 1.5422e-06
# nt_epoch =   3380  elapsed = 04:08 (+00.6)  loss = 1.5349e-06
# nt_epoch =   3390  elapsed = 04:09 (+00.7)  loss = 1.5276e-06
# nt_epoch =   3400  elapsed = 04:09 (+00.6)  loss = 1.5170e-06
# nt_epoch =   3410  elapsed = 04:10 (+00.7)  loss = 1.5094e-06
# nt_epoch =   3420  elapsed = 04:11 (+00.7)  loss = 1.5040e-06
# nt_epoch =   3430  elapsed = 04:11 (+00.7)  loss = 1.4960e-06
# nt_epoch =   3440  elapsed = 04:12 (+00.7)  loss = 1.4904e-06
# nt_epoch =   3450  elapsed = 04:13 (+00.7)  loss = 1.4853e-06
# nt_epoch =   3460  elapsed = 04:13 (+00.7)  loss = 1.4779e-06
# nt_epoch =   3470  elapsed = 04:14 (+00.6)  loss = 1.4721e-06
# nt_epoch =   3480  elapsed = 04:15 (+00.6)  loss = 1.4626e-06
# nt_epoch =   3490  elapsed = 04:16 (+00.7)  loss = 1.4509e-06
# nt_epoch =   3500  elapsed = 04:16 (+00.7)  loss = 1.4427e-06
# nt_epoch =   3510  elapsed = 04:17 (+00.7)  loss = 1.4284e-06
# nt_epoch =   3520  elapsed = 04:18 (+00.7)  loss = 1.4162e-06
# nt_epoch =   3530  elapsed = 04:18 (+00.7)  loss = 1.4062e-06
# nt_epoch =   3540  elapsed = 04:19 (+00.6)  loss = 1.3957e-06
# nt_epoch =   3550  elapsed = 04:20 (+00.7)  loss = 1.3858e-06
# nt_epoch =   3560  elapsed = 04:21 (+00.7)  loss = 1.3768e-06
# nt_epoch =   3570  elapsed = 04:21 (+00.6)  loss = 1.3630e-06
# nt_epoch =   3580  elapsed = 04:22 (+00.7)  loss = 1.3616e-06
# nt_epoch =   3590  elapsed = 04:23 (+00.6)  loss = 1.3607e-06
# nt_epoch =   3600  elapsed = 04:23 (+00.7)  loss = 1.3599e-06
# nt_epoch =   3610  elapsed = 04:24 (+00.7)  loss = 1.3592e-06
# nt_epoch =   3620  elapsed = 04:25 (+00.7)  loss = 1.3586e-06
# nt_epoch =   3630  elapsed = 04:26 (+00.7)  loss = 1.3580e-06
# nt_epoch =   3640  elapsed = 04:26 (+00.7)  loss = 1.3575e-06
# nt_epoch =   3650  elapsed = 04:27 (+00.7)  loss = 1.3570e-06
# nt_epoch =   3660  elapsed = 04:28 (+00.6)  loss = 1.3566e-06
# nt_epoch =   3670  elapsed = 04:28 (+00.7)  loss = 1.3562e-06
# nt_epoch =   3680  elapsed = 04:29 (+00.7)  loss = 1.3558e-06
# nt_epoch =   3690  elapsed = 04:30 (+00.7)  loss = 1.3554e-06
# nt_epoch =   3700  elapsed = 04:31 (+00.7)  loss = 1.3550e-06
# nt_epoch =   3710  elapsed = 04:31 (+00.7)  loss = 1.3546e-06
# nt_epoch =   3720  elapsed = 04:32 (+00.6)  loss = 1.3543e-06
# nt_epoch =   3730  elapsed = 04:33 (+00.7)  loss = 1.3539e-06
# nt_epoch =   3740  elapsed = 04:33 (+00.7)  loss = 1.3536e-06
# nt_epoch =   3750  elapsed = 04:34 (+00.6)  loss = 1.3533e-06
# nt_epoch =   3760  elapsed = 04:35 (+00.7)  loss = 1.3530e-06
# nt_epoch =   3770  elapsed = 04:36 (+00.7)  loss = 1.3527e-06
# nt_epoch =   3780  elapsed = 04:36 (+00.6)  loss = 1.3524e-06
# nt_epoch =   3790  elapsed = 04:37 (+00.7)  loss = 1.3521e-06
# nt_epoch =   3800  elapsed = 04:38 (+00.7)  loss = 1.3519e-06
# nt_epoch =   3810  elapsed = 04:38 (+00.6)  loss = 1.3516e-06
# nt_epoch =   3820  elapsed = 04:39 (+00.7)  loss = 1.3513e-06
# nt_epoch =   3830  elapsed = 04:40 (+00.7)  loss = 1.3511e-06
# nt_epoch =   3840  elapsed = 04:40 (+00.7)  loss = 1.3508e-06
# nt_epoch =   3850  elapsed = 04:41 (+00.6)  loss = 1.3506e-06
# nt_epoch =   3860  elapsed = 04:42 (+00.7)  loss = 1.3503e-06
# nt_epoch =   3870  elapsed = 04:43 (+00.7)  loss = 1.3501e-06
# nt_epoch =   3880  elapsed = 04:43 (+00.6)  loss = 1.3499e-06
# nt_epoch =   3890  elapsed = 04:44 (+00.6)  loss = 1.3496e-06
# nt_epoch =   3900  elapsed = 04:45 (+00.6)  loss = 1.3494e-06
# nt_epoch =   3910  elapsed = 04:45 (+00.7)  loss = 1.3492e-06
# nt_epoch =   3920  elapsed = 04:46 (+00.7)  loss = 1.3490e-06
# nt_epoch =   3930  elapsed = 04:47 (+00.7)  loss = 1.3487e-06
# nt_epoch =   3940  elapsed = 04:48 (+00.7)  loss = 1.3485e-06
# nt_epoch =   3950  elapsed = 04:48 (+00.6)  loss = 1.3483e-06
# nt_epoch =   3960  elapsed = 04:49 (+00.7)  loss = 1.3481e-06
# nt_epoch =   3970  elapsed = 04:50 (+00.7)  loss = 1.3479e-06
# nt_epoch =   3980  elapsed = 04:50 (+00.7)  loss = 1.3477e-06
# nt_epoch =   3990  elapsed = 04:51 (+00.6)  loss = 1.3475e-06
# nt_epoch =   4000  elapsed = 04:52 (+00.7)  loss = 1.3473e-06
# nt_epoch =   4010  elapsed = 04:53 (+00.7)  loss = 1.3471e-06
# nt_epoch =   4020  elapsed = 04:53 (+00.7)  loss = 1.3470e-06
# nt_epoch =   4030  elapsed = 04:54 (+00.6)  loss = 1.3468e-06
# nt_epoch =   4040  elapsed = 04:55 (+00.7)  loss = 1.3466e-06
# nt_epoch =   4050  elapsed = 04:55 (+00.6)  loss = 1.3464e-06
# nt_epoch =   4060  elapsed = 04:56 (+00.7)  loss = 1.3462e-06
# nt_epoch =   4070  elapsed = 04:57 (+00.7)  loss = 1.3460e-06
# nt_epoch =   4080  elapsed = 04:58 (+00.7)  loss = 1.3459e-06
# nt_epoch =   4090  elapsed = 04:58 (+00.6)  loss = 1.3457e-06
# nt_epoch =   4100  elapsed = 04:59 (+00.7)  loss = 1.3455e-06
# nt_epoch =   4110  elapsed = 05:00 (+00.7)  loss = 1.3454e-06
# nt_epoch =   4120  elapsed = 05:00 (+00.6)  loss = 1.3452e-06
# nt_epoch =   4130  elapsed = 05:01 (+00.7)  loss = 1.3450e-06
# nt_epoch =   4140  elapsed = 05:02 (+00.7)  loss = 1.3448e-06
# nt_epoch =   4150  elapsed = 05:02 (+00.6)  loss = 1.3447e-06
# nt_epoch =   4160  elapsed = 05:03 (+00.6)  loss = 1.3445e-06
# nt_epoch =   4170  elapsed = 05:04 (+00.7)  loss = 1.3444e-06
# nt_epoch =   4180  elapsed = 05:05 (+00.7)  loss = 1.3442e-06
# nt_epoch =   4190  elapsed = 05:05 (+00.7)  loss = 1.3440e-06
# nt_epoch =   4200  elapsed = 05:06 (+00.7)  loss = 1.3439e-06
# nt_epoch =   4210  elapsed = 05:07 (+00.7)  loss = 1.3437e-06
# nt_epoch =   4220  elapsed = 05:07 (+00.7)  loss = 1.3436e-06
# nt_epoch =   4230  elapsed = 05:08 (+00.7)  loss = 1.3434e-06
# nt_epoch =   4240  elapsed = 05:09 (+00.7)  loss = 1.3433e-06
# nt_epoch =   4250  elapsed = 05:10 (+00.7)  loss = 1.3431e-06
# nt_epoch =   4260  elapsed = 05:10 (+00.7)  loss = 1.3430e-06
# nt_epoch =   4270  elapsed = 05:11 (+00.7)  loss = 1.3428e-06
# nt_epoch =   4280  elapsed = 05:12 (+00.7)  loss = 1.3427e-06
# nt_epoch =   4290  elapsed = 05:13 (+00.7)  loss = 1.3425e-06
# nt_epoch =   4300  elapsed = 05:13 (+00.7)  loss = 1.3424e-06
# nt_epoch =   4310  elapsed = 05:14 (+00.7)  loss = 1.3422e-06
# nt_epoch =   4320  elapsed = 05:15 (+00.7)  loss = 1.3421e-06
# nt_epoch =   4330  elapsed = 05:15 (+00.7)  loss = 1.3420e-06
# nt_epoch =   4340  elapsed = 05:16 (+00.7)  loss = 1.3418e-06
# nt_epoch =   4350  elapsed = 05:17 (+00.7)  loss = 1.3417e-06
# nt_epoch =   4360  elapsed = 05:18 (+00.7)  loss = 1.3415e-06
# nt_epoch =   4370  elapsed = 05:18 (+00.7)  loss = 1.3414e-06
# nt_epoch =   4380  elapsed = 05:19 (+00.7)  loss = 1.3413e-06
# nt_epoch =   4390  elapsed = 05:20 (+00.7)  loss = 1.3411e-06
# nt_epoch =   4400  elapsed = 05:20 (+00.6)  loss = 1.3410e-06
# nt_epoch =   4410  elapsed = 05:21 (+00.6)  loss = 1.3409e-06
# nt_epoch =   4420  elapsed = 05:22 (+00.7)  loss = 1.3407e-06
# nt_epoch =   4430  elapsed = 05:23 (+00.6)  loss = 1.3406e-06
# nt_epoch =   4440  elapsed = 05:23 (+00.6)  loss = 1.3405e-06
# nt_epoch =   4450  elapsed = 05:24 (+00.7)  loss = 1.3403e-06
# nt_epoch =   4460  elapsed = 05:25 (+00.7)  loss = 1.3402e-06
# nt_epoch =   4470  elapsed = 05:25 (+00.6)  loss = 1.3401e-06
# nt_epoch =   4480  elapsed = 05:26 (+00.7)  loss = 1.3399e-06
# nt_epoch =   4490  elapsed = 05:27 (+00.6)  loss = 1.3398e-06
# nt_epoch =   4500  elapsed = 05:27 (+00.7)  loss = 1.3397e-06
# nt_epoch =   4510  elapsed = 05:28 (+00.7)  loss = 1.3396e-06
# nt_epoch =   4520  elapsed = 05:29 (+00.6)  loss = 1.3394e-06
# nt_epoch =   4530  elapsed = 05:30 (+00.7)  loss = 1.3393e-06
# nt_epoch =   4540  elapsed = 05:30 (+00.6)  loss = 1.3392e-06
# nt_epoch =   4550  elapsed = 05:31 (+00.6)  loss = 1.3391e-06
# nt_epoch =   4560  elapsed = 05:32 (+00.7)  loss = 1.3389e-06
# nt_epoch =   4570  elapsed = 05:33 (+00.7)  loss = 1.3388e-06
# nt_epoch =   4580  elapsed = 05:33 (+00.7)  loss = 1.3387e-06
# nt_epoch =   4590  elapsed = 05:34 (+00.7)  loss = 1.3386e-06
# nt_epoch =   4600  elapsed = 05:35 (+00.6)  loss = 1.3384e-06
# nt_epoch =   4610  elapsed = 05:35 (+00.7)  loss = 1.3383e-06
# nt_epoch =   4620  elapsed = 05:36 (+00.7)  loss = 1.3382e-06
# nt_epoch =   4630  elapsed = 05:37 (+00.6)  loss = 1.3381e-06
# nt_epoch =   4640  elapsed = 05:37 (+00.7)  loss = 1.3380e-06
# nt_epoch =   4650  elapsed = 05:38 (+00.6)  loss = 1.3378e-06
# nt_epoch =   4660  elapsed = 05:39 (+00.7)  loss = 1.3377e-06
# nt_epoch =   4670  elapsed = 05:40 (+00.7)  loss = 1.3376e-06
# nt_epoch =   4680  elapsed = 05:40 (+00.7)  loss = 1.3375e-06
# nt_epoch =   4690  elapsed = 05:41 (+00.6)  loss = 1.3374e-06
# nt_epoch =   4700  elapsed = 05:42 (+00.7)  loss = 1.3373e-06
# nt_epoch =   4710  elapsed = 05:42 (+00.7)  loss = 1.3371e-06
# nt_epoch =   4720  elapsed = 05:43 (+00.7)  loss = 1.3370e-06
# nt_epoch =   4730  elapsed = 05:44 (+00.7)  loss = 1.3369e-06
# nt_epoch =   4740  elapsed = 05:44 (+00.6)  loss = 1.3368e-06
# nt_epoch =   4750  elapsed = 05:45 (+00.7)  loss = 1.3367e-06
# nt_epoch =   4760  elapsed = 05:46 (+00.7)  loss = 1.3366e-06
# nt_epoch =   4770  elapsed = 05:47 (+00.7)  loss = 1.3365e-06
# nt_epoch =   4780  elapsed = 05:47 (+00.7)  loss = 1.3364e-06
# nt_epoch =   4790  elapsed = 05:48 (+00.6)  loss = 1.3362e-06
# nt_epoch =   4800  elapsed = 05:49 (+00.7)  loss = 1.3361e-06
# nt_epoch =   4810  elapsed = 05:49 (+00.7)  loss = 1.3360e-06
# nt_epoch =   4820  elapsed = 05:50 (+00.6)  loss = 1.3359e-06
# nt_epoch =   4830  elapsed = 05:51 (+00.7)  loss = 1.3358e-06
# nt_epoch =   4840  elapsed = 05:52 (+00.7)  loss = 1.3357e-06
# nt_epoch =   4850  elapsed = 05:52 (+00.7)  loss = 1.3356e-06
# nt_epoch =   4860  elapsed = 05:53 (+00.6)  loss = 1.3355e-06
# nt_epoch =   4870  elapsed = 05:54 (+00.7)  loss = 1.3354e-06
# nt_epoch =   4880  elapsed = 05:54 (+00.7)  loss = 1.3353e-06
# nt_epoch =   4890  elapsed = 05:55 (+00.7)  loss = 1.3351e-06
# nt_epoch =   4900  elapsed = 05:56 (+00.7)  loss = 1.3350e-06
# nt_epoch =   4910  elapsed = 05:57 (+00.7)  loss = 1.3349e-06
# nt_epoch =   4920  elapsed = 05:57 (+00.7)  loss = 1.3348e-06
# nt_epoch =   4930  elapsed = 05:58 (+00.6)  loss = 1.3347e-06
# nt_epoch =   4940  elapsed = 05:59 (+00.7)  loss = 1.3346e-06
# nt_epoch =   4950  elapsed = 05:59 (+00.7)  loss = 1.3345e-06
# nt_epoch =   4960  elapsed = 06:00 (+00.6)  loss = 1.3344e-06
# nt_epoch =   4970  elapsed = 06:01 (+00.7)  loss = 1.3343e-06
# nt_epoch =   4980  elapsed = 06:02 (+00.7)  loss = 1.3342e-06
# nt_epoch =   4990  elapsed = 06:02 (+00.7)  loss = 1.3341e-06
# ==================
# Training finished (epoch 5200): duration = 06:03  error = 1.4052e-04
#
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 06:03 (+00.8)  loss = 4.9502e-01
# tf_epoch =     10  elapsed = 06:03 (+00.4)  loss = 2.9976e-01
# tf_epoch =     20  elapsed = 06:04 (+00.3)  loss = 1.4612e-01
# tf_epoch =     30  elapsed = 06:04 (+00.3)  loss = 6.7968e-02
# tf_epoch =     40  elapsed = 06:05 (+00.3)  loss = 5.0747e-02
# tf_epoch =     50  elapsed = 06:05 (+00.4)  loss = 4.3113e-02
# tf_epoch =     60  elapsed = 06:06 (+00.4)  loss = 3.6730e-02
# tf_epoch =     70  elapsed = 06:06 (+00.3)  loss = 3.2869e-02
# tf_epoch =     80  elapsed = 06:06 (+00.4)  loss = 3.1191e-02
# tf_epoch =     90  elapsed = 06:07 (+00.4)  loss = 2.9883e-02
# tf_epoch =    100  elapsed = 06:07 (+00.4)  loss = 2.8783e-02
# tf_epoch =    110  elapsed = 06:08 (+00.3)  loss = 2.7772e-02
# tf_epoch =    120  elapsed = 06:08 (+00.3)  loss = 2.6836e-02
# tf_epoch =    130  elapsed = 06:08 (+00.4)  loss = 2.5945e-02
# tf_epoch =    140  elapsed = 06:09 (+00.3)  loss = 2.5087e-02
# tf_epoch =    150  elapsed = 06:09 (+00.3)  loss = 2.4251e-02
# tf_epoch =    160  elapsed = 06:10 (+00.4)  loss = 2.3437e-02
# tf_epoch =    170  elapsed = 06:10 (+00.4)  loss = 2.2653e-02
# tf_epoch =    180  elapsed = 06:10 (+00.4)  loss = 2.1912e-02
# tf_epoch =    190  elapsed = 06:11 (+00.4)  loss = 2.1222e-02
# -- Starting LBFGS optimization --
# nt_epoch =     10  elapsed = 06:12 (+00.9)  loss = 1.9389e-02
# nt_epoch =     20  elapsed = 06:12 (+00.5)  loss = 1.6555e-02
# nt_epoch =     30  elapsed = 06:13 (+00.6)  loss = 1.3486e-02
# nt_epoch =     40  elapsed = 06:14 (+00.6)  loss = 1.0625e-02
# nt_epoch =     50  elapsed = 06:14 (+00.6)  loss = 9.5484e-03
# nt_epoch =     60  elapsed = 06:15 (+00.7)  loss = 8.5558e-03
# nt_epoch =     70  elapsed = 06:16 (+00.7)  loss = 7.7384e-03
# nt_epoch =     80  elapsed = 06:16 (+00.7)  loss = 6.8978e-03
# nt_epoch =     90  elapsed = 06:17 (+00.7)  loss = 5.8837e-03
# nt_epoch =    100  elapsed = 06:18 (+00.7)  loss = 5.1584e-03
# nt_epoch =    110  elapsed = 06:19 (+00.7)  loss = 4.5435e-03
# nt_epoch =    120  elapsed = 06:19 (+00.6)  loss = 4.0712e-03
# nt_epoch =    130  elapsed = 06:20 (+00.6)  loss = 3.7508e-03
# nt_epoch =    140  elapsed = 06:21 (+00.7)  loss = 3.4495e-03
# nt_epoch =    150  elapsed = 06:21 (+00.7)  loss = 3.2590e-03
# nt_epoch =    160  elapsed = 06:22 (+00.7)  loss = 3.0744e-03
# nt_epoch =    170  elapsed = 06:23 (+00.7)  loss = 2.9176e-03
# nt_epoch =    180  elapsed = 06:24 (+00.7)  loss = 2.7164e-03
# nt_epoch =    190  elapsed = 06:24 (+00.7)  loss = 2.4700e-03
# nt_epoch =    200  elapsed = 06:25 (+00.7)  loss = 2.3911e-03
# nt_epoch =    210  elapsed = 06:26 (+00.7)  loss = 2.2566e-03
# nt_epoch =    220  elapsed = 06:26 (+00.7)  loss = 2.1030e-03
# nt_epoch =    230  elapsed = 06:27 (+00.7)  loss = 2.0086e-03
# nt_epoch =    240  elapsed = 06:28 (+00.7)  loss = 1.9364e-03
# nt_epoch =    250  elapsed = 06:29 (+00.7)  loss = 2.5043e-03
# nt_epoch =    260  elapsed = 06:29 (+00.7)  loss = 1.7084e-03
# nt_epoch =    270  elapsed = 06:30 (+00.7)  loss = 1.5697e-03
# nt_epoch =    280  elapsed = 06:31 (+00.7)  loss = 1.4771e-03
# nt_epoch =    290  elapsed = 06:32 (+00.7)  loss = 1.3375e-03
# nt_epoch =    300  elapsed = 06:32 (+00.7)  loss = 1.2458e-03
# nt_epoch =    310  elapsed = 06:33 (+00.7)  loss = 1.1567e-03
# nt_epoch =    320  elapsed = 06:34 (+00.7)  loss = 1.0453e-03
# nt_epoch =    330  elapsed = 06:34 (+00.7)  loss = 1.0035e-03
# nt_epoch =    340  elapsed = 06:35 (+00.7)  loss = 9.0521e-04
# nt_epoch =    350  elapsed = 06:36 (+00.7)  loss = 8.7445e-04
# nt_epoch =    360  elapsed = 06:37 (+00.7)  loss = 7.9605e-04
# nt_epoch =    370  elapsed = 06:37 (+00.7)  loss = 7.5186e-04
# nt_epoch =    380  elapsed = 06:38 (+00.7)  loss = 7.0217e-04
# nt_epoch =    390  elapsed = 06:39 (+00.7)  loss = 6.5861e-04
# nt_epoch =    400  elapsed = 06:39 (+00.7)  loss = 6.1008e-04
# nt_epoch =    410  elapsed = 06:40 (+00.7)  loss = 5.6510e-04
# nt_epoch =    420  elapsed = 06:41 (+00.7)  loss = 5.1928e-04
# nt_epoch =    430  elapsed = 06:42 (+00.7)  loss = 4.8977e-04
# nt_epoch =    440  elapsed = 06:42 (+00.6)  loss = 4.5676e-04
# nt_epoch =    450  elapsed = 06:43 (+00.7)  loss = 4.3229e-04
# nt_epoch =    460  elapsed = 06:44 (+00.7)  loss = 4.1489e-04
# nt_epoch =    470  elapsed = 06:44 (+00.6)  loss = 4.0337e-04
# nt_epoch =    480  elapsed = 06:45 (+00.7)  loss = 3.8720e-04
# nt_epoch =    490  elapsed = 06:46 (+00.7)  loss = 3.7858e-04
# nt_epoch =    500  elapsed = 06:47 (+00.7)  loss = 3.6557e-04
# nt_epoch =    510  elapsed = 06:47 (+00.7)  loss = 3.5788e-04
# nt_epoch =    520  elapsed = 06:48 (+00.7)  loss = 3.4473e-04
# nt_epoch =    530  elapsed = 06:49 (+00.7)  loss = 3.3638e-04
# nt_epoch =    540  elapsed = 06:50 (+00.7)  loss = 3.2525e-04
# nt_epoch =    550  elapsed = 06:50 (+00.7)  loss = 3.1077e-04
# nt_epoch =    560  elapsed = 06:51 (+00.7)  loss = 3.0148e-04
# nt_epoch =    570  elapsed = 06:52 (+00.7)  loss = 2.9003e-04
# nt_epoch =    580  elapsed = 06:52 (+00.7)  loss = 2.7970e-04
# nt_epoch =    590  elapsed = 06:53 (+00.7)  loss = 2.7296e-04
# nt_epoch =    600  elapsed = 06:54 (+00.7)  loss = 2.6121e-04
# nt_epoch =    610  elapsed = 06:55 (+00.7)  loss = 2.5422e-04
# nt_epoch =    620  elapsed = 06:55 (+00.7)  loss = 2.4808e-04
# nt_epoch =    630  elapsed = 06:56 (+00.7)  loss = 2.4072e-04
# nt_epoch =    640  elapsed = 06:57 (+00.7)  loss = 2.3459e-04
# nt_epoch =    650  elapsed = 06:57 (+00.7)  loss = 2.2941e-04
# nt_epoch =    660  elapsed = 06:58 (+00.7)  loss = 2.2273e-04
# nt_epoch =    670  elapsed = 06:59 (+00.7)  loss = 2.1603e-04
# nt_epoch =    680  elapsed = 07:00 (+00.7)  loss = 2.2266e-04
# nt_epoch =    690  elapsed = 07:00 (+00.6)  loss = 2.0603e-04
# nt_epoch =    700  elapsed = 07:01 (+00.7)  loss = 2.0208e-04
# nt_epoch =    710  elapsed = 07:02 (+00.7)  loss = 1.9972e-04
# nt_epoch =    720  elapsed = 07:02 (+00.7)  loss = 1.9315e-04
# nt_epoch =    730  elapsed = 07:03 (+00.7)  loss = 1.8919e-04
# nt_epoch =    740  elapsed = 07:04 (+00.7)  loss = 1.8166e-04
# nt_epoch =    750  elapsed = 07:05 (+00.7)  loss = 1.7321e-04
# nt_epoch =    760  elapsed = 07:05 (+00.7)  loss = 1.6609e-04
# nt_epoch =    770  elapsed = 07:06 (+00.7)  loss = 1.6053e-04
# nt_epoch =    780  elapsed = 07:07 (+00.7)  loss = 1.5318e-04
# nt_epoch =    790  elapsed = 07:07 (+00.7)  loss = 1.4977e-04
# nt_epoch =    800  elapsed = 07:08 (+00.7)  loss = 1.4707e-04
# nt_epoch =    810  elapsed = 07:09 (+00.7)  loss = 1.4113e-04
# nt_epoch =    820  elapsed = 07:10 (+00.7)  loss = 1.3260e-04
# nt_epoch =    830  elapsed = 07:10 (+00.7)  loss = 1.2650e-04
# nt_epoch =    840  elapsed = 07:11 (+00.7)  loss = 1.2293e-04
# nt_epoch =    850  elapsed = 07:12 (+00.7)  loss = 1.1594e-04
# nt_epoch =    860  elapsed = 07:12 (+00.7)  loss = 1.1277e-04
# nt_epoch =    870  elapsed = 07:13 (+00.7)  loss = 1.0857e-04
# nt_epoch =    880  elapsed = 07:14 (+00.7)  loss = 1.0350e-04
# nt_epoch =    890  elapsed = 07:15 (+00.7)  loss = 9.8881e-05
# nt_epoch =    900  elapsed = 07:15 (+00.7)  loss = 9.5216e-05
# nt_epoch =    910  elapsed = 07:16 (+00.7)  loss = 9.2820e-05
# nt_epoch =    920  elapsed = 07:17 (+00.7)  loss = 8.9791e-05
# nt_epoch =    930  elapsed = 07:17 (+00.7)  loss = 8.7374e-05
# nt_epoch =    940  elapsed = 07:18 (+00.7)  loss = 8.5881e-05
# nt_epoch =    950  elapsed = 07:19 (+00.7)  loss = 8.3905e-05
# nt_epoch =    960  elapsed = 07:20 (+00.7)  loss = 8.1946e-05
# nt_epoch =    970  elapsed = 07:20 (+00.7)  loss = 7.9802e-05
# nt_epoch =    980  elapsed = 07:21 (+00.7)  loss = 7.8232e-05
# nt_epoch =    990  elapsed = 07:22 (+00.7)  loss = 7.6567e-05
# nt_epoch =   1000  elapsed = 07:22 (+00.7)  loss = 7.4863e-05
# nt_epoch =   1010  elapsed = 07:23 (+00.7)  loss = 7.2414e-05
# nt_epoch =   1020  elapsed = 07:24 (+00.6)  loss = 7.0746e-05
# nt_epoch =   1030  elapsed = 07:25 (+00.7)  loss = 6.9295e-05
# nt_epoch =   1040  elapsed = 07:25 (+00.7)  loss = 6.8038e-05
# nt_epoch =   1050  elapsed = 07:26 (+00.7)  loss = 6.6918e-05
# nt_epoch =   1060  elapsed = 07:27 (+00.7)  loss = 6.5311e-05
# nt_epoch =   1070  elapsed = 07:27 (+00.7)  loss = 6.3984e-05
# nt_epoch =   1080  elapsed = 07:28 (+00.6)  loss = 6.2710e-05
# nt_epoch =   1090  elapsed = 07:29 (+00.7)  loss = 6.1877e-05
# nt_epoch =   1100  elapsed = 07:30 (+00.7)  loss = 6.0248e-05
# nt_epoch =   1110  elapsed = 07:30 (+00.7)  loss = 5.8611e-05
# nt_epoch =   1120  elapsed = 07:31 (+00.7)  loss = 5.7207e-05
# nt_epoch =   1130  elapsed = 07:32 (+00.7)  loss = 5.4277e-05
# nt_epoch =   1140  elapsed = 07:32 (+00.7)  loss = 5.2517e-05
# nt_epoch =   1150  elapsed = 07:33 (+00.7)  loss = 5.0526e-05
# nt_epoch =   1160  elapsed = 07:34 (+00.7)  loss = 4.9259e-05
# nt_epoch =   1170  elapsed = 07:35 (+00.7)  loss = 4.7842e-05
# nt_epoch =   1180  elapsed = 07:35 (+00.7)  loss = 4.6675e-05
# nt_epoch =   1190  elapsed = 07:36 (+00.7)  loss = 4.5891e-05
# nt_epoch =   1200  elapsed = 07:37 (+00.7)  loss = 4.5206e-05
# nt_epoch =   1210  elapsed = 07:37 (+00.7)  loss = 4.4232e-05
# nt_epoch =   1220  elapsed = 07:38 (+00.7)  loss = 4.3012e-05
# nt_epoch =   1230  elapsed = 07:39 (+00.7)  loss = 4.2128e-05
# nt_epoch =   1240  elapsed = 07:40 (+00.7)  loss = 3.9967e-05
# nt_epoch =   1250  elapsed = 07:40 (+00.7)  loss = 3.9577e-05
# nt_epoch =   1260  elapsed = 07:41 (+00.7)  loss = 3.8383e-05
# nt_epoch =   1270  elapsed = 07:42 (+00.7)  loss = 3.7539e-05
# nt_epoch =   1280  elapsed = 07:43 (+00.7)  loss = 3.6940e-05
# nt_epoch =   1290  elapsed = 07:43 (+00.6)  loss = 3.6003e-05
# nt_epoch =   1300  elapsed = 07:44 (+00.7)  loss = 3.5202e-05
# nt_epoch =   1310  elapsed = 07:45 (+00.7)  loss = 3.4553e-05
# nt_epoch =   1320  elapsed = 07:45 (+00.6)  loss = 3.3740e-05
# nt_epoch =   1330  elapsed = 07:46 (+00.7)  loss = 3.3265e-05
# nt_epoch =   1340  elapsed = 07:47 (+00.7)  loss = 3.2943e-05
# nt_epoch =   1350  elapsed = 07:47 (+00.7)  loss = 3.2478e-05
# nt_epoch =   1360  elapsed = 07:48 (+00.7)  loss = 3.1936e-05
# nt_epoch =   1370  elapsed = 07:49 (+00.7)  loss = 3.1688e-05
# nt_epoch =   1380  elapsed = 07:50 (+00.7)  loss = 3.1162e-05
# nt_epoch =   1390  elapsed = 07:50 (+00.6)  loss = 3.0501e-05
# nt_epoch =   1400  elapsed = 07:51 (+00.7)  loss = 3.0078e-05
# nt_epoch =   1410  elapsed = 07:52 (+00.7)  loss = 2.9751e-05
# nt_epoch =   1420  elapsed = 07:53 (+00.7)  loss = 2.9540e-05
# nt_epoch =   1430  elapsed = 07:53 (+00.7)  loss = 2.9112e-05
# nt_epoch =   1440  elapsed = 07:54 (+00.7)  loss = 2.8688e-05
# nt_epoch =   1450  elapsed = 07:55 (+00.7)  loss = 2.8424e-05
# nt_epoch =   1460  elapsed = 07:55 (+00.7)  loss = 2.8169e-05
# nt_epoch =   1470  elapsed = 07:56 (+00.7)  loss = 2.7793e-05
# nt_epoch =   1480  elapsed = 07:57 (+00.7)  loss = 2.7501e-05
# nt_epoch =   1490  elapsed = 07:58 (+00.7)  loss = 2.7236e-05
# nt_epoch =   1500  elapsed = 07:58 (+00.7)  loss = 2.6944e-05
# nt_epoch =   1510  elapsed = 07:59 (+00.7)  loss = 2.6727e-05
# nt_epoch =   1520  elapsed = 08:00 (+00.7)  loss = 2.6450e-05
# nt_epoch =   1530  elapsed = 08:00 (+00.7)  loss = 2.6188e-05
# nt_epoch =   1540  elapsed = 08:01 (+00.7)  loss = 2.6042e-05
# nt_epoch =   1550  elapsed = 08:02 (+00.7)  loss = 2.5816e-05
# nt_epoch =   1560  elapsed = 08:03 (+00.6)  loss = 2.5516e-05
# nt_epoch =   1570  elapsed = 08:03 (+00.7)  loss = 2.5206e-05
# nt_epoch =   1580  elapsed = 08:04 (+00.7)  loss = 2.4872e-05
# nt_epoch =   1590  elapsed = 08:05 (+00.7)  loss = 2.4705e-05
# nt_epoch =   1600  elapsed = 08:05 (+00.7)  loss = 2.4388e-05
# nt_epoch =   1610  elapsed = 08:06 (+00.7)  loss = 2.4121e-05
# nt_epoch =   1620  elapsed = 08:07 (+00.7)  loss = 2.3890e-05
# nt_epoch =   1630  elapsed = 08:08 (+00.7)  loss = 2.3747e-05
# nt_epoch =   1640  elapsed = 08:08 (+00.7)  loss = 2.3495e-05
# nt_epoch =   1650  elapsed = 08:09 (+00.7)  loss = 2.3272e-05
# nt_epoch =   1660  elapsed = 08:10 (+00.7)  loss = 2.3043e-05
# nt_epoch =   1670  elapsed = 08:10 (+00.7)  loss = 2.2818e-05
# nt_epoch =   1680  elapsed = 08:11 (+00.7)  loss = 2.2646e-05
# nt_epoch =   1690  elapsed = 08:12 (+00.7)  loss = 2.2530e-05
# nt_epoch =   1700  elapsed = 08:13 (+00.7)  loss = 2.2310e-05
# nt_epoch =   1710  elapsed = 08:13 (+00.7)  loss = 2.1984e-05
# nt_epoch =   1720  elapsed = 08:14 (+00.7)  loss = 2.1814e-05
# nt_epoch =   1730  elapsed = 08:15 (+00.7)  loss = 2.1507e-05
# nt_epoch =   1740  elapsed = 08:16 (+00.7)  loss = 2.1312e-05
# nt_epoch =   1750  elapsed = 08:16 (+00.7)  loss = 2.1096e-05
# nt_epoch =   1760  elapsed = 08:17 (+00.7)  loss = 2.0780e-05
# nt_epoch =   1770  elapsed = 08:18 (+00.7)  loss = 2.0602e-05
# nt_epoch =   1780  elapsed = 08:19 (+00.7)  loss = 2.0377e-05
# nt_epoch =   1790  elapsed = 08:19 (+00.7)  loss = 2.0180e-05
# nt_epoch =   1800  elapsed = 08:20 (+00.7)  loss = 2.0043e-05
# nt_epoch =   1810  elapsed = 08:21 (+00.7)  loss = 1.9956e-05
# nt_epoch =   1820  elapsed = 08:22 (+00.7)  loss = 1.9734e-05
# nt_epoch =   1830  elapsed = 08:22 (+00.7)  loss = 1.9597e-05
# nt_epoch =   1840  elapsed = 08:23 (+00.7)  loss = 1.9417e-05
# nt_epoch =   1850  elapsed = 08:24 (+00.6)  loss = 1.9326e-05
# nt_epoch =   1860  elapsed = 08:24 (+00.7)  loss = 1.9077e-05
# nt_epoch =   1870  elapsed = 08:25 (+00.7)  loss = 1.8902e-05
# nt_epoch =   1880  elapsed = 08:26 (+00.7)  loss = 1.8739e-05
# nt_epoch =   1890  elapsed = 08:27 (+00.7)  loss = 1.8572e-05
# nt_epoch =   1900  elapsed = 08:27 (+00.7)  loss = 1.8436e-05
# nt_epoch =   1910  elapsed = 08:28 (+00.7)  loss = 1.8425e-05
# nt_epoch =   1920  elapsed = 08:29 (+00.7)  loss = 1.8152e-05
# nt_epoch =   1930  elapsed = 08:29 (+00.7)  loss = 1.7958e-05
# nt_epoch =   1940  elapsed = 08:30 (+00.7)  loss = 1.7814e-05
# ...
# nt_epoch =   2540  elapsed = 09:13 (+00.7)  loss = 8.3803e-06
# nt_epoch =   2550  elapsed = 09:14 (+00.7)  loss = 8.3077e-06
# nt_epoch =   2560  elapsed = 09:14 (+00.7)  loss = 8.2252e-06
# nt_epoch =   2570  elapsed = 09:15 (+00.7)  loss = 8.1775e-06
# nt_epoch =   2580  elapsed = 09:16 (+00.7)  loss = 8.1335e-06
# nt_epoch =   2590  elapsed = 09:17 (+00.7)  loss = 8.0607e-06
# nt_epoch =   2600  elapsed = 09:17 (+00.7)  loss = 7.9640e-06
# nt_epoch =   2610  elapsed = 09:18 (+00.7)  loss = 7.8686e-06
# nt_epoch =   2620  elapsed = 09:19 (+00.7)  loss = 7.7659e-06
# nt_epoch =   2630  elapsed = 09:19 (+00.7)  loss = 7.6884e-06
# nt_epoch =   2640  elapsed = 09:20 (+00.7)  loss = 7.6462e-06
# nt_epoch =   2650  elapsed = 09:21 (+00.7)  loss = 7.5588e-06
# nt_epoch =   2660  elapsed = 09:22 (+00.6)  loss = 7.4735e-06
# nt_epoch =   2670  elapsed = 09:22 (+00.7)  loss = 7.4198e-06
# nt_epoch =   2680  elapsed = 09:23 (+00.7)  loss = 7.3432e-06
# nt_epoch =   2690  elapsed = 09:24 (+00.7)  loss = 7.2882e-06
# nt_epoch =   2700  elapsed = 09:24 (+00.7)  loss = 7.2486e-06
# nt_epoch =   2710  elapsed = 09:25 (+00.7)  loss = 7.1868e-06
# nt_epoch =   2720  elapsed = 09:26 (+00.7)  loss = 7.1098e-06
# nt_epoch =   2730  elapsed = 09:27 (+00.7)  loss = 7.0420e-06
# nt_epoch =   2740  elapsed = 09:27 (+00.7)  loss = 7.0391e-06
# nt_epoch =   2750  elapsed = 09:28 (+00.7)  loss = 6.9141e-06
# nt_epoch =   2760  elapsed = 09:29 (+00.7)  loss = 6.8812e-06
# nt_epoch =   2770  elapsed = 09:29 (+00.7)  loss = 6.8206e-06
# nt_epoch =   2780  elapsed = 09:30 (+00.7)  loss = 6.7599e-06
# nt_epoch =   2790  elapsed = 09:31 (+00.7)  loss = 6.6423e-06
# nt_epoch =   2800  elapsed = 09:32 (+00.7)  loss = 6.5872e-06
# nt_epoch =   2810  elapsed = 09:32 (+00.7)  loss = 7.3369e-06
# nt_epoch =   2820  elapsed = 09:33 (+00.7)  loss = 6.4732e-06
# nt_epoch =   2830  elapsed = 09:34 (+00.7)  loss = 6.4313e-06
# nt_epoch =   2840  elapsed = 09:34 (+00.7)  loss = 6.3692e-06
# nt_epoch =   2850  elapsed = 09:35 (+00.7)  loss = 6.2616e-06
# nt_epoch =   2860  elapsed = 09:36 (+00.7)  loss = 6.2290e-06
# nt_epoch =   2870  elapsed = 09:37 (+00.7)  loss = 6.1754e-06
# nt_epoch =   2880  elapsed = 09:37 (+00.7)  loss = 6.1228e-06
# nt_epoch =   2890  elapsed = 09:38 (+00.7)  loss = 6.0563e-06
# nt_epoch =   2900  elapsed = 09:39 (+00.7)  loss = 5.9980e-06
# nt_epoch =   2910  elapsed = 09:39 (+00.7)  loss = 5.9459e-06
# nt_epoch =   3290  elapsed = 10:07 (+00.7)  loss = 4.3692e-06
# nt_epoch =   3300  elapsed = 10:07 (+00.7)  loss = 4.3268e-06
# nt_epoch =   3310  elapsed = 10:08 (+00.7)  loss = 4.2706e-06
# nt_epoch =   3320  elapsed = 10:09 (+00.7)  loss = 4.2055e-06
# nt_epoch =   3330  elapsed = 10:10 (+00.7)  loss = 4.1590e-06
# nt_epoch =   3340  elapsed = 10:10 (+00.7)  loss = 4.0912e-06
# nt_epoch =   3350  elapsed = 10:11 (+00.7)  loss = 4.0270e-06
# nt_epoch =   3360  elapsed = 10:12 (+00.7)  loss = 3.9898e-06
# nt_epoch =   3370  elapsed = 10:12 (+00.7)  loss = 3.9151e-06
# nt_epoch =   3380  elapsed = 10:13 (+00.7)  loss = 3.8788e-06
# nt_epoch =   3390  elapsed = 10:14 (+00.7)  loss = 3.8620e-06
# nt_epoch =   3400  elapsed = 10:14 (+00.7)  loss = 3.8297e-06
# nt_epoch =   3410  elapsed = 10:15 (+00.6)  loss = 3.7839e-06
# nt_epoch =   3420  elapsed = 10:16 (+00.7)  loss = 3.7619e-06
# nt_epoch =   3430  elapsed = 10:17 (+00.7)  loss = 3.7181e-06
# nt_epoch =   3440  elapsed = 10:17 (+00.7)  loss = 3.6951e-06
# nt_epoch =   3450  elapsed = 10:18 (+00.7)  loss = 3.6672e-06
# nt_epoch =   3460  elapsed = 10:19 (+00.7)  loss = 3.6447e-06
# nt_epoch =   3470  elapsed = 10:19 (+00.7)  loss = 3.6177e-06
# nt_epoch =   3480  elapsed = 10:20 (+00.7)  loss = 3.5831e-06
# nt_epoch =   3490  elapsed = 10:21 (+00.7)  loss = 3.5669e-06
# nt_epoch =   3500  elapsed = 10:22 (+00.7)  loss = 3.5381e-06
# nt_epoch =   3510  elapsed = 10:22 (+00.7)  loss = 3.5165e-06
# nt_epoch =   3520  elapsed = 10:23 (+00.7)  loss = 3.4687e-06
# nt_epoch =   3530  elapsed = 10:24 (+00.6)  loss = 3.4261e-06
# nt_epoch =   3540  elapsed = 10:24 (+00.7)  loss = 3.4049e-06
# nt_epoch =   3550  elapsed = 10:25 (+00.6)  loss = 3.3818e-06
# nt_epoch =   3560  elapsed = 10:26 (+00.7)  loss = 3.3604e-06
# nt_epoch =   3570  elapsed = 10:27 (+00.7)  loss = 3.3375e-06
# nt_epoch =   3580  elapsed = 10:27 (+00.7)  loss = 3.3124e-06
# nt_epoch =   3590  elapsed = 10:28 (+00.7)  loss = 3.2967e-06
# nt_epoch =   3600  elapsed = 10:29 (+00.7)  loss = 3.2858e-06
# nt_epoch =   3610  elapsed = 10:29 (+00.7)  loss = 3.2697e-06
# nt_epoch =   3620  elapsed = 10:30 (+00.7)  loss = 3.2599e-06
# nt_epoch =   3630  elapsed = 10:31 (+00.7)  loss = 3.2472e-06
# nt_epoch =   3640  elapsed = 10:32 (+00.7)  loss = 3.2297e-06
# nt_epoch =   3650  elapsed = 10:32 (+00.7)  loss = 3.2051e-06
# nt_epoch =   3660  elapsed = 10:33 (+00.7)  loss = 3.1754e-06
# nt_epoch =   3670  elapsed = 10:34 (+00.7)  loss = 3.1627e-06
# nt_epoch =   3680  elapsed = 10:34 (+00.7)  loss = 3.1458e-06
# nt_epoch =   3690  elapsed = 10:35 (+00.7)  loss = 3.1209e-06
# nt_epoch =   3700  elapsed = 10:36 (+00.7)  loss = 3.1030e-06
# nt_epoch =   3710  elapsed = 10:37 (+00.7)  loss = 3.0890e-06
# nt_epoch =   3720  elapsed = 10:37 (+00.7)  loss = 3.0812e-06
# nt_epoch =   3730  elapsed = 10:38 (+00.7)  loss = 3.0579e-06
# nt_epoch =   3740  elapsed = 10:39 (+00.7)  loss = 3.0435e-06
# nt_epoch =   3750  elapsed = 10:40 (+00.7)  loss = 3.0242e-06
# nt_epoch =   3760  elapsed = 10:40 (+00.7)  loss = 3.0052e-06
# nt_epoch =   3770  elapsed = 10:41 (+00.7)  loss = 2.9689e-06
# nt_epoch =   3780  elapsed = 10:42 (+00.7)  loss = 2.9460e-06
# nt_epoch =   3790  elapsed = 10:42 (+00.7)  loss = 2.9307e-06
# nt_epoch =   3800  elapsed = 10:43 (+00.7)  loss = 2.9114e-06
# nt_epoch =   3810  elapsed = 10:44 (+00.7)  loss = 2.9014e-06
# nt_epoch =   3820  elapsed = 10:45 (+00.7)  loss = 2.8858e-06
# nt_epoch =   3830  elapsed = 10:45 (+00.6)  loss = 2.8678e-06
# nt_epoch =   3840  elapsed = 10:46 (+00.7)  loss = 2.8364e-06
# nt_epoch =   3850  elapsed = 10:47 (+00.7)  loss = 2.8119e-06
# nt_epoch =   3860  elapsed = 10:47 (+00.7)  loss = 2.8035e-06
# nt_epoch =   3870  elapsed = 10:48 (+00.7)  loss = 2.7856e-06
# nt_epoch =   3880  elapsed = 10:49 (+00.7)  loss = 2.7675e-06
# nt_epoch =   3890  elapsed = 10:50 (+00.6)  loss = 2.7510e-06
# nt_epoch =   3900  elapsed = 10:50 (+00.7)  loss = 2.7398e-06
# nt_epoch =   3910  elapsed = 10:51 (+00.7)  loss = 2.7276e-06
# nt_epoch =   3920  elapsed = 10:52 (+00.7)  loss = 2.7139e-06
# nt_epoch =   3930  elapsed = 10:52 (+00.7)  loss = 2.6989e-06
# nt_epoch =   3940  elapsed = 10:53 (+00.7)  loss = 2.6811e-06
# nt_epoch =   3950  elapsed = 10:54 (+00.7)  loss = 2.6556e-06
# nt_epoch =   3960  elapsed = 10:55 (+00.7)  loss = 2.6433e-06
# nt_epoch =   3970  elapsed = 10:55 (+00.7)  loss = 2.6335e-06
# nt_epoch =   3980  elapsed = 10:56 (+00.7)  loss = 2.6204e-06
# nt_epoch =   3990  elapsed = 10:57 (+00.7)  loss = 2.6062e-06
# nt_epoch =   4000  elapsed = 10:57 (+00.7)  loss = 2.5911e-06
# nt_epoch =   4010  elapsed = 10:58 (+00.7)  loss = 2.5773e-06
# nt_epoch =   4020  elapsed = 10:59 (+00.7)  loss = 2.5571e-06
# nt_epoch =   4030  elapsed = 10:59 (+00.7)  loss = 2.5384e-06
# nt_epoch =   4420  elapsed = 11:27 (+00.7)  loss = 2.0111e-06
# nt_epoch =   4430  elapsed = 11:28 (+00.6)  loss = 2.0106e-06
# nt_epoch =   4440  elapsed = 11:29 (+00.6)  loss = 2.0102e-06
# nt_epoch =   4450  elapsed = 11:29 (+00.7)  loss = 2.0098e-06
# nt_epoch =   4460  elapsed = 11:30 (+00.6)  loss = 2.0094e-06
# nt_epoch =   4470  elapsed = 11:31 (+00.7)  loss = 2.0091e-06
# nt_epoch =   4480  elapsed = 11:31 (+00.7)  loss = 2.0087e-06
# nt_epoch =   4490  elapsed = 11:32 (+00.6)  loss = 2.0084e-06
# nt_epoch =   4500  elapsed = 11:33 (+00.7)  loss = 2.0080e-06
# nt_epoch =   4510  elapsed = 11:34 (+00.7)  loss = 2.0077e-06
# nt_epoch =   4520  elapsed = 11:34 (+00.6)  loss = 2.0074e-06
# nt_epoch =   4530  elapsed = 11:35 (+00.7)  loss = 2.0071e-06
# nt_epoch =   4540  elapsed = 11:36 (+00.7)  loss = 2.0068e-06
# nt_epoch =   4550  elapsed = 11:36 (+00.7)  loss = 2.0065e-06
# nt_epoch =   4560  elapsed = 11:37 (+00.7)  loss = 2.0063e-06
# nt_epoch =   4570  elapsed = 11:38 (+00.7)  loss = 2.0060e-06
# nt_epoch =   4580  elapsed = 11:38 (+00.7)  loss = 2.0057e-06
# nt_epoch =   4590  elapsed = 11:39 (+00.6)  loss = 2.0055e-06
# nt_epoch =   4600  elapsed = 11:40 (+00.6)  loss = 2.0052e-06
# nt_epoch =   4610  elapsed = 11:41 (+00.7)  loss = 2.0050e-06
# nt_epoch =   4620  elapsed = 11:41 (+00.7)  loss = 2.0047e-06
# nt_epoch =   4630  elapsed = 11:42 (+00.7)  loss = 2.0045e-06
# nt_epoch =   4640  elapsed = 11:43 (+00.7)  loss = 2.0043e-06
# nt_epoch =   4650  elapsed = 11:43 (+00.6)  loss = 2.0040e-06
# nt_epoch =   4660  elapsed = 11:44 (+00.6)  loss = 2.0038e-06
# nt_epoch =   4670  elapsed = 11:45 (+00.7)  loss = 2.0036e-06
# nt_epoch =   4680  elapsed = 11:46 (+00.7)  loss = 2.0034e-06
# nt_epoch =   4690  elapsed = 11:46 (+00.7)  loss = 2.0032e-06
# nt_epoch =   4700  elapsed = 11:47 (+00.7)  loss = 2.0030e-06
# nt_epoch =   4710  elapsed = 11:48 (+00.7)  loss = 2.0028e-06
# nt_epoch =   4720  elapsed = 11:48 (+00.7)  loss = 2.0026e-06
# nt_epoch =   4730  elapsed = 11:49 (+00.6)  loss = 2.0024e-06
# nt_epoch =   4740  elapsed = 11:50 (+00.7)  loss = 2.0022e-06
# nt_epoch =   4750  elapsed = 11:51 (+00.7)  loss = 2.0020e-06
# nt_epoch =   4760  elapsed = 11:51 (+00.7)  loss = 2.0018e-06
# nt_epoch =   4770  elapsed = 11:52 (+00.7)  loss = 2.0016e-06
# nt_epoch =   4780  elapsed = 11:53 (+00.7)  loss = 2.0014e-06
# nt_epoch =   4790  elapsed = 11:53 (+00.7)  loss = 2.0012e-06
# nt_epoch =   4800  elapsed = 11:54 (+00.7)  loss = 2.0010e-06
# nt_epoch =   4810  elapsed = 11:55 (+00.7)  loss = 2.0008e-06
# nt_epoch =   4820  elapsed = 11:56 (+00.7)  loss = 2.0007e-06
# nt_epoch =   4830  elapsed = 11:56 (+00.7)  loss = 2.0005e-06
# nt_epoch =   4840  elapsed = 11:57 (+00.7)  loss = 2.0003e-06
# nt_epoch =   4850  elapsed = 11:58 (+00.7)  loss = 2.0001e-06
# nt_epoch =   4860  elapsed = 11:59 (+00.7)  loss = 2.0000e-06
# nt_epoch =   4870  elapsed = 11:59 (+00.7)  loss = 1.9998e-06
# nt_epoch =   4880  elapsed = 12:00 (+00.7)  loss = 1.9996e-06
# nt_epoch =   4890  elapsed = 12:01 (+00.7)  loss = 1.9995e-06
# nt_epoch =   4900  elapsed = 12:01 (+00.7)  loss = 1.9993e-06
# nt_epoch =   4910  elapsed = 12:02 (+00.7)  loss = 1.9991e-06
# nt_epoch =   4920  elapsed = 12:03 (+00.7)  loss = 1.9990e-06
# nt_epoch =   4930  elapsed = 12:04 (+00.6)  loss = 1.9988e-06
# nt_epoch =   4940  elapsed = 12:04 (+00.7)  loss = 1.9987e-06
# nt_epoch =   4950  elapsed = 12:05 (+00.7)  loss = 1.9985e-06
# nt_epoch =   4960  elapsed = 12:06 (+00.7)  loss = 1.9983e-06
# nt_epoch =   4970  elapsed = 12:06 (+00.7)  loss = 1.9982e-06
# nt_epoch =   4980  elapsed = 12:07 (+00.7)  loss = 1.9980e-06
# nt_epoch =   4990  elapsed = 12:08 (+00.7)  loss = 1.9979e-06
# ==================
# Training finished (epoch 5200): duration = 12:08  error = 2.1778e-03
# l1:  0.9997204579862482
# l2:  0.003183103598473686
# l1_noise:  0.9993270256030484
# l2_noise:  0.003171376694168567

# %%
#%% PLOTTING
plot_ide_cont_results(X_star, u_pred, X_u_train, u_train,
        Exact_u, X, T, x, t, lambda_1_pred, lambda_1_pred_noise, lambda_2_pred, lambda_2_pred_noise)

# %% [markdown]
# implement a pacience callback (or others) to regulate training would be usefull

# %% [markdown]
# # Wider but shallower

# %%
import sys
import json
import os
import tensorflow as tf
import numpy as np
import tensorflow_probability as tfp

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# HYPER PARAMETERS

hp = {}
# Data size on the solution u
hp["N_u"] = 2000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 100, 100, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 200
hp["tf_lr"] = 0.01
hp["tf_b1"] = 0.9
hp["tf_eps"] = None
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 5000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 10

#%% DEFINING THE MODEL

class BurgersInformedNN(NeuralNetwork):
    def __init__(self, hp, logger, ub, lb):
        super().__init__(hp, logger, ub, lb)

        # Defining the two additional trainable variables for identification
        self.lambda_1 = tf.Variable([0.0], dtype=self.dtype)
        self.lambda_2 = tf.Variable([-6.0], dtype=self.dtype)

  # The actual PINN
    def f_model(self, X_u):
      l1, l2 = self.get_params()
    # Separating the collocation coordinates
      x_f = tf.convert_to_tensor(X_u[:, 0:1], dtype=self.dtype)
      t_f = tf.convert_to_tensor(X_u[:, 1:2], dtype=self.dtype)

      # Using the new GradientTape paradigm of TF2.0,
      # which keeps track of operations to get the gradient at runtime
      with tf.GradientTape(persistent=True) as tape:
        # Watching the two inputs we’ll need later, x and t
        tape.watch(x_f)
        tape.watch(t_f)
        # Packing together the inputs
        X_f = tf.stack([x_f[:,0], t_f[:,0]], axis=1)


        # Getting the prediction
        u = self.model(X_f)
        # Deriving INSIDE the tape (since we’ll need the x derivative of this later, u_xx)
        u_x = tape.gradient(u, x_f)

      # Getting the other derivatives
      u_xx = tape.gradient(u_x, x_f)
      u_t = tape.gradient(u, t_f)

      # Letting the tape go
      del tape

      # Buidling the PINNs
      return u_t + l1*u*u_x - l2*u_xx

  # Defining custom loss
    def loss(self, u, u_pred):
        f_pred = self.f_model(self.X_u)
        return tf.reduce_mean(tf.square(u - u_pred)) + \
              tf.reduce_mean(tf.square(f_pred))

    def wrap_training_variables(self):
      var = self.model.trainable_variables
      var.extend([self.lambda_1, self.lambda_2])
      return var

    def get_weights(self):
        w = super().get_weights(convert_to_tensor=False)
        w.extend(self.lambda_1.numpy())
        w.extend(self.lambda_2.numpy())
        return tf.convert_to_tensor(w, dtype=self.dtype)

    def set_weights(self, w):
      super().set_weights(w)
      self.lambda_1.assign([w[-2]])
      self.lambda_2.assign([w[-1]])

    def get_params(self, numpy=False):
      l1 = self.lambda_1
      l2 = tf.exp(self.lambda_2)
      if numpy:
          return l1.numpy()[0], l2.numpy()[0]
      return l1, l2

    def fit(self, X_u, u):
      self.X_u =  tf.convert_to_tensor(X_u, dtype=self.dtype)
      super().fit(X_u, u)

    def predict(self, X_star):
      u_star = self.model(X_star)
      f_star = self.f_model(X_star)
      return u_star.numpy(), f_star.numpy()

# %% TRAINING THE MODEL


# Getting the data
path = os.path.join("/content/drive/MyDrive/PINNs-TF2.0/1d-burgers/data", "burgers_shock.mat")
x, t, X, T, Exact_u, X_star, u_star, \
        X_u_train, u_train, ub, lb = prep_data(path, hp["N_u"], noise=0.0)
lambdas_star = (1.0, 0.01/np.pi)

# Creating the model
logger = Logger(hp)
pinn = BurgersInformedNN(hp, logger, ub, lb)

# Defining the error function for the logger and training
def error():
  l1, l2 = pinn.get_params(numpy=True)
  l1_star, l2_star = lambdas_star
  error_lambda_1 = np.abs(l1 - l1_star) / l1_star
  error_lambda_2 = np.abs(l2 - l2_star) / l2_star
  return (error_lambda_1 + error_lambda_2) / 2

logger.set_error_fn(error)
pinn.fit(X_u_train, u_train)

# Getting the model predictions, from the same (x,t) that the predictions were previously gotten from
u_pred, f_pred = pinn.predict(X_star)
lambda_1_pred, lambda_2_pred = pinn.get_params(numpy=True)

# Noise case
x, t, X, T, Exact_u, X_star, u_star, \
        X_u_train, u_train, ub, lb = prep_data(path, hp["N_u"], noise=0.01)
pinn = BurgersInformedNN(hp, logger, ub, lb)
pinn.fit(X_u_train, u_train)
lambda_1_pred_noise, lambda_2_pred_noise = pinn.get_params(numpy=True)

print("l1: ", lambda_1_pred)
print("l2: ", lambda_2_pred)
print("l1_noise: ", lambda_1_pred_noise)
print("l2_noise: ", lambda_2_pred_noise)

# %%
#%% PLOTTING
plot_ide_cont_results(X_star, u_pred, X_u_train, u_train,
        Exact_u, X, T, x, t, lambda_1_pred, lambda_1_pred_noise, lambda_2_pred, lambda_2_pred_noise)

# %% [markdown]
# Comment:
# This number of layers can not capture the non-linearity of the PDE.
